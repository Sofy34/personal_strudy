# %% [markdown]
# ## dataset
# [] short sentenses are merge into long
# [] doc packed per paragraph
# [] 3 paragraphs build single sequence
# [] sequence from sentences where seq_len is length of document - features include neighbors -2,-1,+1,+2 of entire document

# %%
import pandas as pd
import os,sys, imp
sys.path.append('./src/')
import doc_utils_clean as doc_utils
import feature_utils
import defines
import numpy as np
from sklearn_crfsuite import scorers, CRF
from sklearn_crfsuite import metrics
from sklearn_crfsuite.metrics import flat_classification_report
from sklearn.model_selection import LeaveOneGroupOut,LeavePGroupsOut,GroupKFold

from operator import itemgetter
from sklearn_crfsuite.utils import flatten
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
import random
import model_utils
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dir_name="merged_sent"

# %%
db_path = os.path.join(os.getcwd(),defines.PATH_TO_DFS,dir_name)

# %%
imp.reload(doc_utils)
doc_db =  pd.read_csv("./dataframes/doc_db.csv")
doc_db.sort_values(by='doc_idx_from_name',inplace=True)
doc_db
# Out:
#                                                  path              file_name  \
# 0   /scratch/sim_reg6/users/zsofya/classroom/MSc/p...   01_aingimel3_lc.docx
# 1   /scratch/sim_reg6/users/zsofya/classroom/MSc/p...  02_aingimel12_lc.docx
# 2   /scratch/sim_reg6/users/zsofya/classroom/MSc/p...  03_aingimel26_lc.docx
# 3   /scratch/sim_reg6/users/zsofya/classroom/MSc/p...        04_nun2_lc.docx
# 4   /scratch/sim_reg6/users/zsofya/classroom/MSc/p...   05_kafhey_23_lc.docx
# ..                                                ...                    ...
# 75  /scratch/sim_reg6/users/zsofya/classroom/MSc/p...       76_nun2_Mor.docx
# 76  /scratch/sim_reg6/users/zsofya/classroom/MSc/p...      77_nun25_Mor.docx
# 77  /scratch/sim_reg6/users/zsofya/classroom/MSc/p...   78_tsadek27_Mor.docx
# 78  /scratch/sim_reg6/users/zsofya/classroom/MSc/p...   79_tsadek29_Mor.docx
# 79  /scratch/sim_reg6/users/zsofya/classroom/MSc/p...      80_nun28_Mor.docx
#
#     doc_idx_from_name  par_count  sent_count  nar_sent_count
# 0                   1 205.000000  580.000000      256.000000
# 1                   2 157.000000  632.000000       70.000000
# 2                   3 118.000000  559.000000      102.000000
# 3                   4 132.000000  460.000000      172.000000
# 4                   5  65.000000  510.000000      270.000000
# ..                ...        ...         ...             ...
# 75                 76 132.000000  464.000000      164.000000
# 76                 77 176.000000  406.000000       64.000000
# 77                 78 122.000000  178.000000       44.000000
# 78                 79 173.000000  252.000000       70.000000
# 79                 80 225.000000  491.000000      102.000000
#
# [80 rows x 6 columns]

# %%
imp.reload(doc_utils)
imp.reload(defines)
imp.reload(feature_utils)
doc_utils.parse_all_docs(merge_short_sent=1)
# Out:
# Creating doc_db
# ERROR: file /scratch/sim_reg6/users/zsofya/classroom/MSc/personal_study/thesis/./tmp/long_sent does not exists
# 1 Doc 580 sentences saved
# Finished doc 0 of 80
# 2 Doc 632 sentences saved
# Finished doc 1 of 80
# 3 Doc 559 sentences saved
# Finished doc 2 of 80
# 4 Doc 460 sentences saved
# Finished doc 3 of 80
# 5 Doc 510 sentences saved
# 58 Doc 572 sentences saved
# Finished doc 57 of 80
# 59 Doc 652 sentences saved
# Finished doc 58 of 80
# 60 Doc 432 sentences saved
# Finished doc 59 of 80
# 61 Doc 637 sentences saved
# Finished doc 60 of 80
# 62 Doc 395 sentences saved
# Finished doc 61 of 80
# 63 Doc 533 sentences saved
# Finished doc 62 of 80
# 64 Doc 743 sentences saved
# Finished doc 63 of 80
# 65 Doc 655 sentences saved
# Finished doc 64 of 80
# 66 Doc 777 sentences saved
# Finished doc 65 of 80
# 67 Doc 810 sentences saved
# Finished doc 66 of 80
# 68 Doc 898 sentences saved
# Finished doc 67 of 80
# 69 Doc 968 sentences saved
# Finished doc 68 of 80
# 70 Doc 251 sentences saved
# Finished doc 69 of 80
# 71 Doc 627 sentences saved
# Finished doc 70 of 80
# 72 Doc 813 sentences saved
# Finished doc 71 of 80
# 73 Doc 395 sentences saved
# Finished doc 72 of 80
# 74 Doc 425 sentences saved
# Finished doc 73 of 80
# 75 Doc 317 sentences saved
# Finished doc 74 of 80
# 76 Doc 464 sentences saved
# Finished doc 75 of 80
# 77 Doc 406 sentences saved
# Finished doc 76 of 80
# 78 Doc 178 sentences saved
# Finished doc 77 of 80
# 79 Doc 252 sentences saved
# Finished doc 78 of 80
# 80 Doc 491 sentences saved
# Finished doc 79 of 80
# 1 sent lemma db saved
# 1 sent count db saved
# 1 sent features db saved
# 1 doc sent saved
# 1 sim_db sent saved
# 2 sent lemma db saved
# 2 sent count db saved
# 2 sent features db saved
# 2 doc sent saved
# 2 sim_db sent saved
# 3 sent lemma db saved
# 3 sent count db saved
# 3 sent features db saved
# 3 doc sent saved
# 3 sim_db sent saved
# 4 sent lemma db saved
# 4 sent count db saved
# 4 sent features db saved
# 4 doc sent saved
# 4 sim_db sent saved
# 5 sent lemma db saved
# 5 sent count db saved
# 5 sent features db saved
# 5 doc sent saved
# 5 sim_db sent saved
# 6 sent lemma db saved
# 6 sent count db saved
# 6 sent features db saved
# 6 doc sent saved
# 6 sim_db sent saved
# 7 sent lemma db saved
# 7 sent count db saved
# 7 sent features db saved
# 7 doc sent saved
# 7 sim_db sent saved
# 8 sent lemma db saved
# 8 sent count db saved
# 8 sent features db saved
# 8 doc sent saved
# 8 sim_db sent saved
# 9 sent lemma db saved
# 9 sent count db saved
# 9 sent features db saved
# 9 doc sent saved
# 9 sim_db sent saved
# 10 sent lemma db saved
# 10 sent count db saved
# 10 sent features db saved
# 10 doc sent saved
# 10 sim_db sent saved
# 11 sent lemma db saved
# 11 sent count db saved
# 11 sent features db saved
# 11 doc sent saved
# 11 sim_db sent saved
# 12 sent lemma db saved
# 12 sent count db saved
# 12 sent features db saved
# 12 doc sent saved
# 12 sim_db sent saved
# 13 sent lemma db saved
# 13 sent count db saved
# 13 sent features db saved
# 13 doc sent saved
# 13 sim_db sent saved
# 14 sent lemma db saved
# 14 sent count db saved
# 14 sent features db saved
# 14 doc sent saved
# 14 sim_db sent saved
# 15 sent lemma db saved
# 15 sent count db saved
# 15 sent features db saved
# 15 doc sent saved
# 15 sim_db sent saved
# 16 sent lemma db saved
# 16 sent count db saved
# 16 sent features db saved
# 16 doc sent saved
# 16 sim_db sent saved
# 17 sent lemma db saved
# 17 sent count db saved
# 17 sent features db saved
# 17 doc sent saved
# 17 sim_db sent saved
# 18 sent lemma db saved
# 18 sent count db saved
# 18 sent features db saved
# 18 doc sent saved
# 18 sim_db sent saved
# 19 sent lemma db saved
# 19 sent count db saved
# 19 sent features db saved
# 19 doc sent saved
# 19 sim_db sent saved
# 20 sent lemma db saved
# 20 sent count db saved
# 20 sent features db saved
# 20 doc sent saved
# 20 sim_db sent saved
# 21 sent lemma db saved
# 21 sent count db saved
# 21 sent features db saved
# 21 doc sent saved
# 21 sim_db sent saved
# 22 sent lemma db saved
# 22 sent count db saved
# 22 sent features db saved
# 22 doc sent saved
# 22 sim_db sent saved
# 23 sent lemma db saved
# 23 sent count db saved
# 23 sent features db saved
# 23 doc sent saved
# 23 sim_db sent saved
# 24 sent lemma db saved
# 24 sent count db saved
# 24 sent features db saved
# 24 doc sent saved
# 24 sim_db sent saved
# 25 sent lemma db saved
# 25 sent count db saved
# 25 sent features db saved
# 25 doc sent saved
# 25 sim_db sent saved
# 26 sent lemma db saved
# 26 sent count db saved
# 26 sent features db saved
# 26 doc sent saved
# 26 sim_db sent saved
# 27 sent lemma db saved
# 27 sent count db saved
# 27 sent features db saved
# 27 doc sent saved
# 27 sim_db sent saved
# 28 sent lemma db saved
# 28 sent count db saved
# 28 sent features db saved
# 28 doc sent saved
# 28 sim_db sent saved
# 29 sent lemma db saved
# 29 sent count db saved
# 29 sent features db saved
# 29 doc sent saved
# 29 sim_db sent saved
# 30 sent lemma db saved
# 30 sent count db saved
# 30 sent features db saved
# 30 doc sent saved
# 30 sim_db sent saved
# 31 sent lemma db saved
# 31 sent count db saved
# 31 sent features db saved
# 31 doc sent saved
# 31 sim_db sent saved
# 32 sent lemma db saved
# 32 sent count db saved
# 32 sent features db saved
# 32 doc sent saved
# 32 sim_db sent saved
# 33 sent lemma db saved
# 33 sent count db saved
# 33 sent features db saved
# 33 doc sent saved
# 33 sim_db sent saved
# 34 sent lemma db saved
# 34 sent count db saved
# 34 sent features db saved
# 34 doc sent saved
# 34 sim_db sent saved
# 35 sent lemma db saved
# 35 sent count db saved
# 35 sent features db saved
# 35 doc sent saved
# 35 sim_db sent saved
# 36 sent lemma db saved
# 36 sent count db saved
# 36 sent features db saved
# 36 doc sent saved
# 36 sim_db sent saved
# 37 sent lemma db saved
# 37 sent count db saved
# 37 sent features db saved
# 37 doc sent saved
# 37 sim_db sent saved
# 38 sent lemma db saved
# 38 sent count db saved
# 38 sent features db saved
# 38 doc sent saved
# 38 sim_db sent saved
# 39 sent lemma db saved
# 39 sent count db saved
# 39 sent features db saved
# 39 doc sent saved
# 39 sim_db sent saved
# 40 sent lemma db saved
# 40 sent count db saved
# 40 sent features db saved
# 40 doc sent saved
# 40 sim_db sent saved
# 41 sent lemma db saved
# 41 sent count db saved
# 41 sent features db saved
# 41 doc sent saved
# 41 sim_db sent saved
# 42 sent lemma db saved
# 42 sent count db saved
# 42 sent features db saved
# 42 doc sent saved
# 42 sim_db sent saved
# 43 sent lemma db saved
# 43 sent count db saved
# 43 sent features db saved
# 43 doc sent saved
# 43 sim_db sent saved
# 44 sent lemma db saved
# 44 sent count db saved
# 44 sent features db saved
# 44 doc sent saved
# 44 sim_db sent saved
# 45 sent lemma db saved
# 45 sent count db saved
# 45 sent features db saved
# 45 doc sent saved
# 45 sim_db sent saved
# 46 sent lemma db saved
# 46 sent count db saved
# 46 sent features db saved
# 46 doc sent saved
# 46 sim_db sent saved
# 47 sent lemma db saved
# 47 sent count db saved
# 47 sent features db saved
# 47 doc sent saved
# 47 sim_db sent saved
# 48 sent lemma db saved
# 48 sent count db saved
# 48 sent features db saved
# 48 doc sent saved
# 48 sim_db sent saved
# 49 sent lemma db saved
# 49 sent count db saved
# 49 sent features db saved
# 49 doc sent saved
# 49 sim_db sent saved
# 50 sent lemma db saved
# 50 sent count db saved
# 50 sent features db saved
# 50 doc sent saved
# 50 sim_db sent saved
# 51 sent lemma db saved
# 51 sent count db saved
# 51 sent features db saved
# 51 doc sent saved
# 51 sim_db sent saved
# 52 sent lemma db saved
# 52 sent count db saved
# 52 sent features db saved
# 52 doc sent saved
# 52 sim_db sent saved
# 53 sent lemma db saved
# 53 sent count db saved
# 53 sent features db saved
# 53 doc sent saved
# 53 sim_db sent saved
# 54 sent lemma db saved
# 54 sent count db saved
# 54 sent features db saved
# 54 doc sent saved
# 54 sim_db sent saved
# 55 sent lemma db saved
# 55 sent count db saved
# 55 sent features db saved
# 55 doc sent saved
# 55 sim_db sent saved
# 56 sent lemma db saved
# 56 sent count db saved
# 56 sent features db saved
# 56 doc sent saved
# 56 sim_db sent saved
# 57 sent lemma db saved
# 57 sent count db saved
# 57 sent features db saved
# 57 doc sent saved
# 57 sim_db sent saved
# 58 sent lemma db saved
# 58 sent count db saved
# 58 sent features db saved
# 58 doc sent saved
# 58 sim_db sent saved
# 59 sent lemma db saved
# 59 sent count db saved
# 59 sent features db saved
# 59 doc sent saved
# 59 sim_db sent saved
# 60 sent lemma db saved
# 60 sent count db saved
# 60 sent features db saved
# 60 doc sent saved
# 60 sim_db sent saved
# 61 sent lemma db saved
# 61 sent count db saved
# 61 sent features db saved
# 61 doc sent saved
# 61 sim_db sent saved
# 62 sent lemma db saved
# 62 sent count db saved
# 62 sent features db saved
# 62 doc sent saved
# 62 sim_db sent saved
# 63 sent lemma db saved
# 63 sent count db saved
# 63 sent features db saved
# 63 doc sent saved
# 63 sim_db sent saved
# 64 sent lemma db saved
# 64 sent count db saved
# 64 sent features db saved
# 64 doc sent saved
# 64 sim_db sent saved
# 65 sent lemma db saved
# 65 sent count db saved
# 65 sent features db saved
# 65 doc sent saved
# 65 sim_db sent saved
# 66 sent lemma db saved
# 66 sent count db saved
# 66 sent features db saved
# 66 doc sent saved
# 66 sim_db sent saved
# 67 sent lemma db saved
# 67 sent count db saved
# 67 sent features db saved
# 67 doc sent saved
# 67 sim_db sent saved
# 68 sent lemma db saved
# 68 sent count db saved
# 68 sent features db saved
# 68 doc sent saved
# 68 sim_db sent saved
# 69 sent lemma db saved
# 69 sent count db saved
# 69 sent features db saved
# 69 doc sent saved
# 69 sim_db sent saved
# 70 sent lemma db saved
# 70 sent count db saved
# 70 sent features db saved
# 70 doc sent saved
# 70 sim_db sent saved
# 71 sent lemma db saved
# 71 sent count db saved
# 71 sent features db saved
# 71 doc sent saved
# 71 sim_db sent saved
# 72 sent lemma db saved
# 72 sent count db saved
# 72 sent features db saved
# 72 doc sent saved
# 72 sim_db sent saved
# 73 sent lemma db saved
# 73 sent count db saved
# 73 sent features db saved
# 73 doc sent saved
# 73 sim_db sent saved
# 74 sent lemma db saved
# 74 sent count db saved
# 74 sent features db saved
# 74 doc sent saved
# 74 sim_db sent saved
# 75 sent lemma db saved
# 75 sent count db saved
# 75 sent features db saved
# 75 doc sent saved
# 75 sim_db sent saved
# 76 sent lemma db saved
# 76 sent count db saved
# 76 sent features db saved
# 76 doc sent saved
# 76 sim_db sent saved
# 77 sent lemma db saved
# 77 sent count db saved
# 77 sent features db saved
# 77 doc sent saved
# 77 sim_db sent saved
# 78 sent lemma db saved
# 78 sent count db saved
# 78 sent features db saved
# 78 doc sent saved
# 78 sim_db sent saved
# 79 sent lemma db saved
# 79 sent count db saved
# 79 sent features db saved
# 79 doc sent saved
# 79 sim_db sent saved
# 80 sent lemma db saved
# 80 sent count db saved
# 80 sent features db saved
# 80 doc sent saved
# 80 sim_db sent saved

# %%
imp.reload(feature_utils)
ft = feature_utils.load_fasstex_model()

for doc_idx in doc_db['doc_idx_from_name']:
    feature_utils.save_doc_features('merged_sent',int(doc_idx),ft)
# Out:
# 1 sent lemma db saved
# 1 sent count db saved
# 1 sent features db saved
# 1 doc sent saved
# 1 sim_db sent saved
# 2 sent lemma db saved
# 2 sent count db saved
# 2 sent features db saved
# 2 doc sent saved
# 2 sim_db sent saved
# 3 sent lemma db saved
# 3 sent count db saved
# 3 sent features db saved
# 3 doc sent saved
# 3 sim_db sent saved
# 4 sent lemma db saved
# 4 sent count db saved
# 4 sent features db saved
# 4 doc sent saved
# 4 sim_db sent saved
# 5 sent lemma db saved
# 5 sent count db saved
# 5 sent features db saved
# 5 doc sent saved
# 5 sim_db sent saved
# 6 sent lemma db saved
# 6 sent count db saved
# 6 sent features db saved
# 6 doc sent saved
# 6 sim_db sent saved
# 7 sent lemma db saved
# 7 sent count db saved
# 7 sent features db saved
# 7 doc sent saved
# 7 sim_db sent saved
# 8 sent lemma db saved
# 8 sent count db saved
# 8 sent features db saved
# 8 doc sent saved
# 8 sim_db sent saved
# 9 sent lemma db saved
# 9 sent count db saved
# 9 sent features db saved
# 9 doc sent saved
# 9 sim_db sent saved
# 10 sent lemma db saved
# 10 sent count db saved
# 10 sent features db saved
# 10 doc sent saved
# 10 sim_db sent saved
# 11 sent lemma db saved
# 11 sent count db saved
# 11 sent features db saved
# 11 doc sent saved
# 11 sim_db sent saved
# 12 sent lemma db saved
# 12 sent count db saved
# 12 sent features db saved
# 12 doc sent saved
# 12 sim_db sent saved
# 13 sent lemma db saved
# 13 sent count db saved
# 13 sent features db saved
# 13 doc sent saved
# 13 sim_db sent saved
# 14 sent lemma db saved
# 14 sent count db saved
# 14 sent features db saved
# 14 doc sent saved
# 14 sim_db sent saved
# 15 sent lemma db saved
# 15 sent count db saved
# 15 sent features db saved
# 15 doc sent saved
# 15 sim_db sent saved
# 16 sent lemma db saved
# 16 sent count db saved
# 16 sent features db saved
# 16 doc sent saved
# 16 sim_db sent saved
# 17 sent lemma db saved
# 17 sent count db saved
# 17 sent features db saved
# 17 doc sent saved
# 17 sim_db sent saved
# 18 sent lemma db saved
# 18 sent count db saved
# 18 sent features db saved
# 18 doc sent saved
# 18 sim_db sent saved
# 19 sent lemma db saved
# 19 sent count db saved
# 19 sent features db saved
# 19 doc sent saved
# 19 sim_db sent saved
# 20 sent lemma db saved
# 20 sent count db saved
# 20 sent features db saved
# 20 doc sent saved
# 20 sim_db sent saved
# 21 sent lemma db saved
# 21 sent count db saved
# 21 sent features db saved
# 21 doc sent saved
# 21 sim_db sent saved
# 22 sent lemma db saved
# 22 sent count db saved
# 22 sent features db saved
# 22 doc sent saved
# 22 sim_db sent saved
# 23 sent lemma db saved
# 23 sent count db saved
# 23 sent features db saved
# 23 doc sent saved
# 23 sim_db sent saved
# 24 sent lemma db saved
# 24 sent count db saved
# 24 sent features db saved
# 24 doc sent saved
# 24 sim_db sent saved
# 25 sent lemma db saved
# 25 sent count db saved
# 25 sent features db saved
# 25 doc sent saved
# 25 sim_db sent saved
# 26 sent lemma db saved
# 26 sent count db saved
# 26 sent features db saved
# 26 doc sent saved
# 26 sim_db sent saved
# 27 sent lemma db saved
# 27 sent count db saved
# 27 sent features db saved
# 27 doc sent saved
# 27 sim_db sent saved
# 28 sent lemma db saved
# 28 sent count db saved
# 28 sent features db saved
# 28 doc sent saved
# 28 sim_db sent saved
# 29 sent lemma db saved
# 29 sent count db saved
# 29 sent features db saved
# 29 doc sent saved
# 29 sim_db sent saved
# 30 sent lemma db saved
# 30 sent count db saved
# 30 sent features db saved
# 30 doc sent saved
# 30 sim_db sent saved
# 31 sent lemma db saved
# 31 sent count db saved
# 31 sent features db saved
# 31 doc sent saved
# 31 sim_db sent saved
# 32 sent lemma db saved
# 32 sent count db saved
# 32 sent features db saved
# 32 doc sent saved
# 32 sim_db sent saved
# 33 sent lemma db saved
# 33 sent count db saved
# 33 sent features db saved
# 33 doc sent saved
# 33 sim_db sent saved
# 34 sent lemma db saved
# 34 sent count db saved
# 34 sent features db saved
# 34 doc sent saved
# 34 sim_db sent saved
# 35 sent lemma db saved
# 35 sent count db saved
# 35 sent features db saved
# 35 doc sent saved
# 35 sim_db sent saved
# 36 sent lemma db saved
# 36 sent count db saved
# 36 sent features db saved
# 36 doc sent saved
# 36 sim_db sent saved
# 37 sent lemma db saved
# 37 sent count db saved
# 37 sent features db saved
# 37 doc sent saved
# 37 sim_db sent saved
# 38 sent lemma db saved
# 38 sent count db saved
# 38 sent features db saved
# 38 doc sent saved
# 38 sim_db sent saved
# 39 sent lemma db saved
# 39 sent count db saved
# 39 sent features db saved
# 39 doc sent saved
# 39 sim_db sent saved
# 40 sent lemma db saved
# 40 sent count db saved
# 40 sent features db saved
# 40 doc sent saved
# 40 sim_db sent saved
# 41 sent lemma db saved
# 41 sent count db saved
# 41 sent features db saved
# 41 doc sent saved
# 41 sim_db sent saved
# 42 sent lemma db saved
# 42 sent count db saved
# 42 sent features db saved
# 42 doc sent saved
# 42 sim_db sent saved
# 43 sent lemma db saved
# 43 sent count db saved
# 43 sent features db saved
# 43 doc sent saved
# 43 sim_db sent saved
# 44 sent lemma db saved
# 44 sent count db saved
# 44 sent features db saved
# 44 doc sent saved
# 44 sim_db sent saved
# 45 sent lemma db saved
# 45 sent count db saved
# 45 sent features db saved
# 45 doc sent saved
# 45 sim_db sent saved
# 46 sent lemma db saved
# 46 sent count db saved
# 46 sent features db saved
# 46 doc sent saved
# 46 sim_db sent saved
# 47 sent lemma db saved
# 47 sent count db saved
# 47 sent features db saved
# 47 doc sent saved
# 47 sim_db sent saved
# 48 sent lemma db saved
# 48 sent count db saved
# 48 sent features db saved
# 48 doc sent saved
# 48 sim_db sent saved
# 49 sent lemma db saved
# 49 sent count db saved
# 49 sent features db saved
# 49 doc sent saved
# 49 sim_db sent saved
# 50 sent lemma db saved
# 50 sent count db saved
# 50 sent features db saved
# 50 doc sent saved
# 50 sim_db sent saved
# 51 sent lemma db saved
# 51 sent count db saved
# 51 sent features db saved
# 51 doc sent saved
# 51 sim_db sent saved
# 52 sent lemma db saved
# 52 sent count db saved
# 52 sent features db saved
# 52 doc sent saved
# 52 sim_db sent saved
# 53 sent lemma db saved
# 53 sent count db saved
# 53 sent features db saved
# 53 doc sent saved
# 53 sim_db sent saved
# 54 sent lemma db saved
# 54 sent count db saved
# 54 sent features db saved
# 54 doc sent saved
# 54 sim_db sent saved
# 55 sent lemma db saved
# 55 sent count db saved
# 55 sent features db saved
# 55 doc sent saved
# 55 sim_db sent saved
# 56 sent lemma db saved
# 56 sent count db saved
# 56 sent features db saved
# 56 doc sent saved
# 56 sim_db sent saved
# 57 sent lemma db saved
# 57 sent count db saved
# 57 sent features db saved
# 57 doc sent saved
# 57 sim_db sent saved
# 58 sent lemma db saved
# 58 sent count db saved
# 58 sent features db saved
# 58 doc sent saved
# 58 sim_db sent saved
# 59 sent lemma db saved
# 59 sent count db saved
# 59 sent features db saved
# 59 doc sent saved
# 59 sim_db sent saved
# 60 sent lemma db saved
# 60 sent count db saved
# 60 sent features db saved
# 60 doc sent saved
# 60 sim_db sent saved
# 61 sent lemma db saved
# 61 sent count db saved
# 61 sent features db saved
# 61 doc sent saved
# 61 sim_db sent saved
# 62 sent lemma db saved
# 62 sent count db saved
# 62 sent features db saved
# 62 doc sent saved
# 62 sim_db sent saved
# 63 sent lemma db saved
# 63 sent count db saved
# 63 sent features db saved
# 63 doc sent saved
# 63 sim_db sent saved
# 64 sent lemma db saved
# 64 sent count db saved
# 64 sent features db saved
# 64 doc sent saved
# 64 sim_db sent saved
# 65 sent lemma db saved
# 65 sent count db saved
# 65 sent features db saved
# 65 doc sent saved
# 65 sim_db sent saved
# 66 sent lemma db saved
# 66 sent count db saved
# 66 sent features db saved
# 66 doc sent saved
# 66 sim_db sent saved
# 67 sent lemma db saved
# 67 sent count db saved
# 67 sent features db saved
# 67 doc sent saved
# 67 sim_db sent saved
# 68 sent lemma db saved
# 68 sent count db saved
# 68 sent features db saved
# 68 doc sent saved
# 68 sim_db sent saved
# 69 sent lemma db saved
# 69 sent count db saved
# 69 sent features db saved
# 69 doc sent saved
# 69 sim_db sent saved
# 70 sent lemma db saved
# 70 sent count db saved
# 70 sent features db saved
# 70 doc sent saved
# 70 sim_db sent saved
# 71 sent lemma db saved
# 71 sent count db saved
# 71 sent features db saved
# 71 doc sent saved
# 71 sim_db sent saved
# 72 sent lemma db saved
# 72 sent count db saved
# 72 sent features db saved
# 72 doc sent saved
# 72 sim_db sent saved
# 73 sent lemma db saved
# 73 sent count db saved
# 73 sent features db saved
# 73 doc sent saved
# 73 sim_db sent saved
# 74 sent lemma db saved
# 74 sent count db saved
# 74 sent features db saved
# 74 doc sent saved
# 74 sim_db sent saved
# 75 sent lemma db saved
# 75 sent count db saved
# 75 sent features db saved
# 75 doc sent saved
# 75 sim_db sent saved
# 76 sent lemma db saved
# 76 sent count db saved
# 76 sent features db saved
# 76 doc sent saved
# 76 sim_db sent saved
# 77 sent lemma db saved
# 77 sent count db saved
# 77 sent features db saved
# 77 doc sent saved
# 77 sim_db sent saved
# 78 sent lemma db saved
# 78 sent count db saved
# 78 sent features db saved
# 78 doc sent saved
# 78 sim_db sent saved
# 79 sent lemma db saved
# 79 sent count db saved
# 79 sent features db saved
# 79 doc sent saved
# 79 sim_db sent saved
# 80 sent lemma db saved
# 80 sent count db saved
# 80 sent features db saved
# 80 doc sent saved
# 80 sim_db sent saved

# %%
imp.reload(feature_utils)
docs_map = feature_utils.pack_all_doc_sentences_to_map(dir_name,per_par=True,limit=0,doc_as_sequence=1,sent_lemma_db_list=[])
# Out:
# 67 doc 407 paragraphes packed
# 72 doc 420 paragraphes packed
# 58 doc 384 paragraphes packed
# 79 doc 172 paragraphes packed
# 53 doc 149 paragraphes packed
# 46 doc 200 paragraphes packed
# 11 doc 121 paragraphes packed
# 4 doc 132 paragraphes packed
# 25 doc 122 paragraphes packed
# 30 doc 82 paragraphes packed
# 23 doc 74 paragraphes packed
# 36 doc 87 paragraphes packed
# 9 doc 276 paragraphes packed
# 80 doc 223 paragraphes packed
# 28 doc 167 paragraphes packed
# 17 doc 322 paragraphes packed
# 2 doc 156 paragraphes packed
# 55 doc 249 paragraphes packed
# 40 doc 148 paragraphes packed
# 61 doc 433 paragraphes packed
# 74 doc 95 paragraphes packed
# 52 doc 275 paragraphes packed
# 47 doc 160 paragraphes packed
# 78 doc 122 paragraphes packed
# 59 doc 370 paragraphes packed
# 66 doc 366 paragraphes packed
# 73 doc 85 paragraphes packed
# 24 doc 158 paragraphes packed
# 31 doc 79 paragraphes packed
# 10 doc 123 paragraphes packed
# 5 doc 65 paragraphes packed
# 16 doc 102 paragraphes packed
# 3 doc 113 paragraphes packed
# 29 doc 105 paragraphes packed
# 8 doc 82 paragraphes packed
# 22 doc 89 paragraphes packed
# 37 doc 99 paragraphes packed
# 60 doc 245 paragraphes packed
# 75 doc 68 paragraphes packed
# 54 doc 243 paragraphes packed
# 41 doc 137 paragraphes packed
# 18 doc 62 paragraphes packed
# 32 doc 73 paragraphes packed
# 27 doc 67 paragraphes packed
# 6 doc 420 paragraphes packed
# 13 doc 90 paragraphes packed
# 39 doc 111 paragraphes packed
# 44 doc 199 paragraphes packed
# 51 doc 208 paragraphes packed
# 70 doc 183 paragraphes packed
# 65 doc 335 paragraphes packed
# 49 doc 206 paragraphes packed
# 76 doc 132 paragraphes packed
# 63 doc 338 paragraphes packed
# 42 doc 136 paragraphes packed
# 57 doc 271 paragraphes packed
# 68 doc 439 paragraphes packed
# 15 doc 121 paragraphes packed
# 34 doc 49 paragraphes packed
# 21 doc 108 paragraphes packed
# 38 doc 90 paragraphes packed
# 7 doc 248 paragraphes packed
# 12 doc 150 paragraphes packed
# 33 doc 91 paragraphes packed
# 26 doc 114 paragraphes packed
# 19 doc 265 paragraphes packed
# 71 doc 156 paragraphes packed
# 64 doc 347 paragraphes packed
# 45 doc 204 paragraphes packed
# 50 doc 184 paragraphes packed
# 69 doc 517 paragraphes packed
# 43 doc 99 paragraphes packed
# 56 doc 268 paragraphes packed
# 77 doc 176 paragraphes packed
# 62 doc 248 paragraphes packed
# 48 doc 223 paragraphes packed
# 35 doc 63 paragraphes packed
# 20 doc 90 paragraphes packed
# 1 doc 203 paragraphes packed
# 14 doc 129 paragraphes packed
# 14918 items packed for 80 docs

# %% [markdown]
# ### Flow:
# - Save doc names/statistic
# - Parse doc
# - Calculate POS
# - Calculate vectors
# - Calculate similarity
# - Save docs' features
# - Proceed paragraphs (split long)
# - Pask features to dictionary per doc/ per paragraph

# %%
docs_map[23]['X'][12]
# Out:
# [{'is_question': 0.0,
#   'par_idx_in_doc': 12.0,
#   'sent_len': 88.0,
#   'is_client': 0,
#   'sent_idx_in_par': 0,
#   'TOKEN': 21,
#   'POSTAG_BN': 0.0952380952380952,
#   'POSTAG_DTT': 0.0476190476190476,
#   'POSTAG_IN': 0.1904761904761904,
#   'POSTAG_JJ': 0.0476190476190476,
#   'POSTAG_MD': 0.0476190476190476,
#   'POSTAG_PREPOSITION': 0.0476190476190476,
#   'POSTAG_PRP': 0.3333333333333333,
#   'POSTAG_QW': 0.0476190476190476,
#   'POSTAG_RB': 0.1428571428571428,
#   'POSTAG_REL': 0.0952380952380952,
#   'POSTAG_S_PRN': 0.0952380952380952,
#   'POSTAG_VB': 0.0476190476190476,
#   'f_gen_F': 0.1904761904761904,
#   'f_gen_M': 0.4285714285714285,
#   'f_num_S': 0.6190476190476191,
#   'f_per_1': 0.1904761904761904,
#   'f_per_2': 0.0476190476190476,
#   'f_per_3': 0.1904761904761904,
#   'f_per_A': 0.1428571428571428,
#   '-1:is_question': 0.0,
#   '-1:par_idx_in_doc': 11.0,
#   '-1:sent_len': 48.0,
#   '-1:is_client': 1,
#   '-1:sent_idx_in_par': 3,
#   '-1:TOKEN': 11,
#   '-1:POSTAG_COP': 0.0909090909090909,
#   '-1:POSTAG_DEF': 0.2727272727272727,
#   '-1:POSTAG_DTT': 0.0909090909090909,
#   '-1:POSTAG_IN': 0.1818181818181818,
#   '-1:POSTAG_NN': 0.4545454545454545,
#   '-1:POSTAG_POS': 0.0909090909090909,
#   '-1:POSTAG_PREPOSITION': 0.0909090909090909,
#   '-1:POSTAG_RB': 0.0909090909090909,
#   '-1:POSTAG_S_PRN': 0.0909090909090909,
#   '-1:f_gen_F': 0.1818181818181818,
#   '-1:f_gen_M': 0.4545454545454545,
#   '-1:f_num_P': 0.1818181818181818,
#   '-1:f_num_S': 0.4545454545454545,
#   '-1:f_per_3': 0.1818181818181818,
#   '-2:is_question': 0.0,
#   '-2:par_idx_in_doc': 11.0,
#   '-2:sent_len': 127.0,
#   '-2:is_client': 1,
#   '-2:sent_idx_in_par': 2,
#   '-2:TOKEN': 28,
#   '-2:POSTAG_CC': 0.0357142857142857,
#   '-2:POSTAG_CONJ': 0.0357142857142857,
#   '-2:POSTAG_COP': 0.0357142857142857,
#   '-2:POSTAG_DEF': 0.0714285714285714,
#   '-2:POSTAG_EX': 0.0357142857142857,
#   '-2:POSTAG_IN': 0.1071428571428571,
#   '-2:POSTAG_MD': 0.0714285714285714,
#   '-2:POSTAG_NN': 0.1428571428571428,
#   '-2:POSTAG_NNT': 0.0357142857142857,
#   '-2:POSTAG_PREPOSITION': 0.1785714285714285,
#   '-2:POSTAG_PRP': 0.2142857142857142,
#   '-2:POSTAG_RB': 0.1785714285714285,
#   '-2:POSTAG_REL': 0.0714285714285714,
#   '-2:POSTAG_S_PRN': 0.1071428571428571,
#   '-2:POSTAG_VB': 0.1428571428571428,
#   '-2:f_gen_F': 0.3214285714285714,
#   '-2:f_gen_M': 0.3928571428571428,
#   '-2:f_num_P': 0.0357142857142857,
#   '-2:f_num_S': 0.6785714285714286,
#   '-2:f_suf_gen_M': 0.0357142857142857,
#   '-2:f_suf_num_S': 0.0357142857142857,
#   '-2:f_suf_per_1.0': 0.0357142857142857,
#   '-2:f_per_1': 0.0714285714285714,
#   '-2:f_per_2': 0.0714285714285714,
#   '-2:f_per_3': 0.3214285714285714,
#   '-2:f_per_A': 0.0357142857142857,
#   '-2:f_tense_BEINONI': 0.0357142857142857,
#   '-2:f_tense_FUTURE': 0.0357142857142857,
#   '-2:f_tense_PAST': 0.0714285714285714,
#   '-1.sim': 0.6605276642497987,
#   '+1.sim': 0.4788204002494771,
#   '-2.sim': 0.8126527789207787,
#   '+2.sim': 0.8513831274158028,
#   'tfidf_word_8339': 0.4814212510693836,
#   'tfidf_word_7698': 0.37954724529871664,
#   'tfidf_word_5342': 0.2126299652817875,
#   'tfidf_word_4851': 0.15897593427850779,
#   'tfidf_word_4741': 0.167413213990486,
#   'tfidf_word_4064': 0.1889728828644358,
#   'tfidf_word_3888': 0.31087220382826825,
#   'tfidf_word_3560': 0.2790826924194753,
#   'tfidf_word_3546': 0.19735995739450954,
#   'tfidf_word_2824': 0.20362566056008843,
#   'tfidf_word_2132': 0.25553813356369576,
#   'tfidf_word_2079': 0.21449297903520606,
#   'tfidf_word_1714': 0.1624405220242923,
#   'tfidf_word_1020': 0.1664528608622784,
#   'tfidf_word_823': 0.12997933843741444,
#   'tfidf_word_524': 0.22960087566104784,
#   'tfidf_char_wb_31457': 0.07186308240253188,
#   'tfidf_char_wb_31456': 0.07173711808009278,
#   'tfidf_char_wb_31156': 0.0631684572020206,
#   'tfidf_char_wb_31097': 0.08225388833471588,
#   'tfidf_char_wb_31096': 0.07718253945988315,
#   'tfidf_char_wb_30922': 0.06627022837684342,
#   'tfidf_char_wb_30921': 0.0662274501386586,
#   'tfidf_char_wb_30918': 0.0642271743247202,
#   'tfidf_char_wb_30546': 0.11287001487821058,
#   'tfidf_char_wb_30049': 0.10458926698256141,
#   'tfidf_char_wb_30046': 0.07598374448462303,
#   'tfidf_char_wb_30032': 0.07300695054291269,
#   'tfidf_char_wb_28927': 0.17567715297063694,
#   'tfidf_char_wb_28926': 0.17288776769709469,
#   'tfidf_char_wb_28920': 0.09680307131142825,
#   'tfidf_char_wb_27742': 0.12614498622388778,
#   'tfidf_char_wb_26095': 0.11893863743910416,
#   'tfidf_char_wb_25278': 0.08062050368145555,
#   'tfidf_char_wb_25275': 0.08027671605312182,
#   'tfidf_char_wb_25274': 0.08001546466377905,
#   'tfidf_char_wb_23526': 0.07657952459840384,
#   'tfidf_char_wb_23525': 0.07657952459840384,
#   'tfidf_char_wb_23524': 0.0745072018197254,
#   'tfidf_char_wb_22681': 0.0634533312005571,
#   'tfidf_char_wb_22515': 0.046970890407257604,
#   'tfidf_char_wb_21930': 0.09213585187427191,
#   'tfidf_char_wb_21928': 0.0885263718672456,
#   'tfidf_char_wb_21925': 0.08741356378750777,
#   'tfidf_char_wb_21324': 0.05735956776261242,
#   'tfidf_char_wb_21220': 0.058812318386036774,
#   'tfidf_char_wb_20733': 0.09081402858353209,
#   'tfidf_char_wb_20732': 0.0786919124480119,
#   'tfidf_char_wb_19913': 0.06689476308755339,
#   'tfidf_char_wb_19751': 0.13625620247634634,
#   'tfidf_char_wb_19750': 0.1359179648466867,
#   'tfidf_char_wb_19744': 0.10862709112073116,
#   'tfidf_char_wb_19345': 0.06628451029260032,
#   'tfidf_char_wb_19303': 0.12476796184315973,
#   'tfidf_char_wb_19302': 0.12320856037265071,
#   'tfidf_char_wb_18158': 0.1359179648466867,
#   'tfidf_char_wb_18155': 0.111602834234254,
#   'tfidf_char_wb_18153': 0.08783169966282674,
#   'tfidf_char_wb_18047': 0.08794958402975075,
#   'tfidf_char_wb_18043': 0.07127947042951982,
#   'tfidf_char_wb_18041': 0.06832407310785034,
#   'tfidf_char_wb_17565': 0.0997778244504266,
#   'tfidf_char_wb_17533': 0.07228609324580715,
#   'tfidf_char_wb_17532': 0.07052347394404153,
#   'tfidf_char_wb_17343': 0.08711747483748086,
#   'tfidf_char_wb_17342': 0.08691529188129671,
#   'tfidf_char_wb_17333': 0.06984122454397847,
#   'tfidf_char_wb_17255': 0.12146881930197692,
#   'tfidf_char_wb_17254': 0.12116971850335373,
#   'tfidf_char_wb_15533': 0.06339234298534228,
#   'tfidf_char_wb_13003': 0.09225548990561797,
#   'tfidf_char_wb_13002': 0.09213585187427191,
#   'tfidf_char_wb_12998': 0.0838220978121424,
#   'tfidf_char_wb_11988': 0.059218646603239604,
#   'tfidf_char_wb_11942': 0.09680307131142825,
#   'tfidf_char_wb_11941': 0.09657304465889154,
#   'tfidf_char_wb_11937': 0.07322578356570703,
#   'tfidf_char_wb_11862': 0.07448470935402682,
#   'tfidf_char_wb_11861': 0.07358579329577727,
#   'tfidf_char_wb_11628': 0.15343773037725753,
#   'tfidf_char_wb_10871': 0.10600801474037495,
#   'tfidf_char_wb_10870': 0.088797005123359,
#   'tfidf_char_wb_9951': 0.044492683949496376,
#   'tfidf_char_wb_9609': 0.12448908639463734,
#   'tfidf_char_wb_9608': 0.12441288848503078,
#   'tfidf_char_wb_9290': 0.08387867478264548,
#   'tfidf_char_wb_9289': 0.08367208504562745,
#   'tfidf_char_wb_8970': 0.07656691031673259,
#   'tfidf_char_wb_8969': 0.07639122751611405,
#   'tfidf_char_wb_7803': 0.07234591209805066,
#   'tfidf_char_wb_7802': 0.07222647149063335,
#   'tfidf_char_wb_7799': 0.07172746473959997,
#   'tfidf_char_wb_7555': 0.06726802686548465,
#   'tfidf_char_wb_7553': 0.06527047017348421,
#   'tfidf_char_wb_7508': 0.05245300785796558,
#   'tfidf_char_wb_7118': 0.17288776769709469,
#   'tfidf_char_wb_7115': 0.12371357509372377,
#   'tfidf_char_wb_7103': 0.10977516232469132,
#   'tfidf_char_wb_6819': 0.13914730861858723,
#   'tfidf_char_wb_6818': 0.13914730861858723,
#   'tfidf_char_wb_6011': 0.08062050368145555,
#   'tfidf_char_wb_6010': 0.08036983042492461,
#   'tfidf_char_wb_6004': 0.0754543262718882,
#   'tfidf_char_wb_5212': 0.07711742536902212,
#   'tfidf_char_wb_5211': 0.0753361339096564,
#   'tfidf_char_wb_5203': 0.06849277528997859,
#   'tfidf_char_wb_4771': 0.07183393578738514,
#   'tfidf_char_wb_4770': 0.07112945766300488,
#   'tfidf_char_wb_4727': 0.055468324404479845,
#   'tfidf_char_wb_4726': 0.05364925131480976,
#   'tfidf_char_wb_4519': 0.08994832394534555,
#   'tfidf_char_wb_4517': 0.08882181004338392,
#   'tfidf_char_wb_4506': 0.05248963443217277,
#   'tfidf_char_wb_4239': 0.05863825701686253,
#   'tfidf_char_wb_4238': 0.057609948167203856,
#   'tfidf_char_wb_3618': 0.11423266172081717,
#   'tfidf_char_wb_3616': 0.10482815079940841,
#   'tfidf_char_wb_3603': 0.0934974994980781,
#   'tfidf_char_wb_3575': 0.07136440235958512,
#   'tfidf_char_wb_3573': 0.07102704059023111,
#   'tfidf_char_wb_3532': 0.0640179790893068,
#   'tfidf_char_wb_3437': 0.07924328663189545,
#   'tfidf_char_wb_3436': 0.07801070293454507,
#   'tfidf_char_wb_3431': 0.08182729652925454,
#   'tfidf_char_wb_3430': 0.08160938058185789,
#   'tfidf_char_wb_3428': 0.08119754700414947,
#   'tfidf_char_wb_1486': 0.06133968237897904,
#   'tfidf_char_wb_1485': 0.061307098001042226,
#   'tfidf_char_wb_1001': 0.10818751032236741,
#   'tfidf_char_wb_1000': 0.09056633395261794,
#   'tfidf_char_wb_983': 0.08553922302606835,
#   'tfidf_char_wb_438': 0.08976061165164266,
#   'tfidf_char_wb_437': 0.08969063628695531,
#   'tfidf_char_wb_426': 0.08587104670379525,
#   'tfidf_char_wb_310': 0.08604306586766353,
#   'tfidf_char_wb_309': 0.08583142384888834,
#   'tfidf_char_wb_292': 0.05397555797829794,
#   '+1:is_question': 0.0,
#   '+1:par_idx_in_doc': 12.0,
#   '+1:sent_len': 13.0,
#   '+1:is_client': 0,
#   '+1:sent_idx_in_par': 1,
#   '+1:TOKEN': 3,
#   '+1:POSTAG_DEF': 0.6666666666666666,
#   '+1:POSTAG_NN': 0.3333333333333333,
#   '+1:POSTAG_NNP': 0.3333333333333333,
#   '+1:POSTAG_PRP': 0.3333333333333333,
#   '+1:f_gen_F': 0.6666666666666666,
#   '+1:f_gen_M': 0.3333333333333333,
#   '+1:f_num_S': 1.0,
#   '+1:f_per_3': 0.3333333333333333,
#   '+2:is_question': 0.0,
#   '+2:par_idx_in_doc': 13.0,
#   '+2:sent_len': 31.0,
#   '+2:is_client': 1,
#   '+2:sent_idx_in_par': 0,
#   '+2:TOKEN': 7,
#   '+2:POSTAG_CC': 0.2857142857142857,
#   '+2:POSTAG_PRP': 0.4285714285714285,
#   '+2:POSTAG_RB': 0.1428571428571428,
#   '+2:POSTAG_VB': 0.1428571428571428,
#   '+2:f_gen_M': 0.5714285714285714,
#   '+2:f_num_S': 0.5714285714285714,
#   '+2:f_per_1': 0.4285714285714285,
#   '+2:f_per_3': 0.1428571428571428,
#   '+2:f_tense_PAST': 0.1428571428571428},
#  {'is_question': 0.0,
#   'par_idx_in_doc': 12.0,
#   'sent_len': 13.0,
#   'is_client': 0,
#   'sent_idx_in_par': 1,
#   'TOKEN': 3,
#   'POSTAG_DEF': 0.6666666666666666,
#   'POSTAG_NN': 0.3333333333333333,
#   'POSTAG_NNP': 0.3333333333333333,
#   'POSTAG_PRP': 0.3333333333333333,
#   'f_gen_F': 0.6666666666666666,
#   'f_gen_M': 0.3333333333333333,
#   'f_num_S': 1.0,
#   'f_per_3': 0.3333333333333333,
#   '-1:is_question': 0.0,
#   '-1:par_idx_in_doc': 12.0,
#   '-1:sent_len': 88.0,
#   '-1:is_client': 0,
#   '-1:sent_idx_in_par': 0,
#   '-1:TOKEN': 21,
#   '-1:POSTAG_BN': 0.0952380952380952,
#   '-1:POSTAG_DTT': 0.0476190476190476,
#   '-1:POSTAG_IN': 0.1904761904761904,
#   '-1:POSTAG_JJ': 0.0476190476190476,
#   '-1:POSTAG_MD': 0.0476190476190476,
#   '-1:POSTAG_PREPOSITION': 0.0476190476190476,
#   '-1:POSTAG_PRP': 0.3333333333333333,
#   '-1:POSTAG_QW': 0.0476190476190476,
#   '-1:POSTAG_RB': 0.1428571428571428,
#   '-1:POSTAG_REL': 0.0952380952380952,
#   '-1:POSTAG_S_PRN': 0.0952380952380952,
#   '-1:POSTAG_VB': 0.0476190476190476,
#   '-1:f_gen_F': 0.1904761904761904,
#   '-1:f_gen_M': 0.4285714285714285,
#   '-1:f_num_S': 0.6190476190476191,
#   '-1:f_per_1': 0.1904761904761904,
#   '-1:f_per_2': 0.0476190476190476,
#   '-1:f_per_3': 0.1904761904761904,
#   '-1:f_per_A': 0.1428571428571428,
#   '-2:is_question': 0.0,
#   '-2:par_idx_in_doc': 11.0,
#   '-2:sent_len': 48.0,
#   '-2:is_client': 1,
#   '-2:sent_idx_in_par': 3,
#   '-2:TOKEN': 11,
#   '-2:POSTAG_COP': 0.0909090909090909,
#   '-2:POSTAG_DEF': 0.2727272727272727,
#   '-2:POSTAG_DTT': 0.0909090909090909,
#   '-2:POSTAG_IN': 0.1818181818181818,
#   '-2:POSTAG_NN': 0.4545454545454545,
#   '-2:POSTAG_POS': 0.0909090909090909,
#   '-2:POSTAG_PREPOSITION': 0.0909090909090909,
#   '-2:POSTAG_RB': 0.0909090909090909,
#   '-2:POSTAG_S_PRN': 0.0909090909090909,
#   '-2:f_gen_F': 0.1818181818181818,
#   '-2:f_gen_M': 0.4545454545454545,
#   '-2:f_num_P': 0.1818181818181818,
#   '-2:f_num_S': 0.4545454545454545,
#   '-2:f_per_3': 0.1818181818181818,
#   '-1.sim': 0.4788204002494771,
#   '+1.sim': 0.4703011932249754,
#   '-2.sim': 0.421529921690517,
#   '+2.sim': 0.4933968097554284,
#   'tfidf_word_9879': 0.8163380177629262,
#   'tfidf_word_3546': 0.5775744460715833,
#   'tfidf_char_wb_32980': 0.2386065623065388,
#   'tfidf_char_wb_32979': 0.22564534217842816,
#   'tfidf_char_wb_32973': 0.21431291952582038,
#   'tfidf_char_wb_31156': 0.1402374055737278,
#   'tfidf_char_wb_18049': 0.23954447953233032,
#   'tfidf_char_wb_18048': 0.2386065623065388,
#   'tfidf_char_wb_18041': 0.15168315287852474,
#   'tfidf_char_wb_17533': 0.1604790527562275,
#   'tfidf_char_wb_17532': 0.1565659421810672,
#   'tfidf_char_wb_17348': 0.18226458102315599,
#   'tfidf_char_wb_17347': 0.17845994512585456,
#   'tfidf_char_wb_14993': 0.25990766975435187,
#   'tfidf_char_wb_14990': 0.25520523911869875,
#   'tfidf_char_wb_14986': 0.18740685187694262,
#   'tfidf_char_wb_13306': 0.20880123541098833,
#   'tfidf_char_wb_13305': 0.20022147335826593,
#   'tfidf_char_wb_13304': 0.20022147335826593,
#   'tfidf_char_wb_9951': 0.09877617469957181,
#   'tfidf_char_wb_2729': 0.2609718987812333,
#   'tfidf_char_wb_2726': 0.21364336575387993,
#   'tfidf_char_wb_2695': 0.16464293923395593,
#   'tfidf_char_wb_1944': 0.20040014954472518,
#   'tfidf_char_wb_1943': 0.20040014954472518,
#   'tfidf_char_wb_1942': 0.14055910736389293,
#   'tfidf_char_wb_1646': 0.17784242542213902,
#   '+1:is_question': 0.0,
#   '+1:par_idx_in_doc': 13.0,
#   '+1:sent_len': 31.0,
#   '+1:is_client': 1,
#   '+1:sent_idx_in_par': 0,
#   '+1:TOKEN': 7,
#   '+1:POSTAG_CC': 0.2857142857142857,
#   '+1:POSTAG_PRP': 0.4285714285714285,
#   '+1:POSTAG_RB': 0.1428571428571428,
#   '+1:POSTAG_VB': 0.1428571428571428,
#   '+1:f_gen_M': 0.5714285714285714,
#   '+1:f_num_S': 0.5714285714285714,
#   '+1:f_per_1': 0.4285714285714285,
#   '+1:f_per_3': 0.1428571428571428,
#   '+1:f_tense_PAST': 0.1428571428571428,
#   '+2:is_question': 0.0,
#   '+2:par_idx_in_doc': 13.0,
#   '+2:sent_len': 75.0,
#   '+2:is_client': 1,
#   '+2:sent_idx_in_par': 1,
#   '+2:TOKEN': 16,
#   '+2:POSTAG_AT': 0.0625,
#   '+2:POSTAG_BN': 0.25,
#   '+2:POSTAG_CC': 0.0625,
#   '+2:POSTAG_CONJ': 0.0625,
#   '+2:POSTAG_IN': 0.0625,
#   '+2:POSTAG_JJ': 0.0625,
#   '+2:POSTAG_NN': 0.125,
#   '+2:POSTAG_PRP': 0.1875,
#   '+2:POSTAG_RB': 0.1875,
#   '+2:POSTAG_REL': 0.125,
#   '+2:f_gen_F': 0.25,
#   '+2:f_gen_M': 0.375,
#   '+2:f_num_P': 0.0625,
#   '+2:f_num_S': 0.5625,
#   '+2:f_per_1': 0.0625,
#   '+2:f_per_3': 0.125,
#   '+2:f_per_A': 0.25}]

# %%
imp.reload(feature_utils)
imp.reload(model_utils)
seq_len=3
step=3
per_par=True
feature_utils.reshape_docs_map_to_seq(docs_map,per_par,seq_len,step)
# Out:
# doc paragraphs reshaped: from 407 to 136
# doc paragraphs reshaped: from 420 to 140
# doc paragraphs reshaped: from 384 to 128
# doc paragraphs reshaped: from 172 to 58
# doc paragraphs reshaped: from 149 to 50
# doc paragraphs reshaped: from 200 to 67
# doc paragraphs reshaped: from 121 to 41
# doc paragraphs reshaped: from 132 to 44
# doc paragraphs reshaped: from 122 to 41
# doc paragraphs reshaped: from 82 to 28
# doc paragraphs reshaped: from 74 to 25
# doc paragraphs reshaped: from 87 to 29
# doc paragraphs reshaped: from 276 to 92
# doc paragraphs reshaped: from 223 to 75
# doc paragraphs reshaped: from 167 to 56
# doc paragraphs reshaped: from 322 to 108
# doc paragraphs reshaped: from 156 to 52
# doc paragraphs reshaped: from 249 to 83
# doc paragraphs reshaped: from 148 to 50
# doc paragraphs reshaped: from 433 to 145
# doc paragraphs reshaped: from 95 to 32
# doc paragraphs reshaped: from 275 to 92
# doc paragraphs reshaped: from 160 to 54
# doc paragraphs reshaped: from 122 to 41
# doc paragraphs reshaped: from 370 to 124
# doc paragraphs reshaped: from 366 to 122
# doc paragraphs reshaped: from 85 to 29
# doc paragraphs reshaped: from 158 to 53
# doc paragraphs reshaped: from 79 to 27
# doc paragraphs reshaped: from 123 to 41
# doc paragraphs reshaped: from 65 to 22
# doc paragraphs reshaped: from 102 to 34
# doc paragraphs reshaped: from 113 to 38
# doc paragraphs reshaped: from 105 to 35
# doc paragraphs reshaped: from 82 to 28
# doc paragraphs reshaped: from 89 to 30
# doc paragraphs reshaped: from 99 to 33
# doc paragraphs reshaped: from 245 to 82
# doc paragraphs reshaped: from 68 to 23
# doc paragraphs reshaped: from 243 to 81
# doc paragraphs reshaped: from 137 to 46
# doc paragraphs reshaped: from 62 to 21
# doc paragraphs reshaped: from 73 to 25
# doc paragraphs reshaped: from 67 to 23
# doc paragraphs reshaped: from 420 to 140
# doc paragraphs reshaped: from 90 to 30
# doc paragraphs reshaped: from 111 to 37
# doc paragraphs reshaped: from 199 to 67
# doc paragraphs reshaped: from 208 to 70
# doc paragraphs reshaped: from 183 to 61
# doc paragraphs reshaped: from 335 to 112
# doc paragraphs reshaped: from 206 to 69
# doc paragraphs reshaped: from 132 to 44
# doc paragraphs reshaped: from 338 to 113
# doc paragraphs reshaped: from 136 to 46
# doc paragraphs reshaped: from 271 to 91
# doc paragraphs reshaped: from 439 to 147
# doc paragraphs reshaped: from 121 to 41
# doc paragraphs reshaped: from 49 to 17
# doc paragraphs reshaped: from 108 to 36
# doc paragraphs reshaped: from 90 to 30
# doc paragraphs reshaped: from 248 to 83
# doc paragraphs reshaped: from 150 to 50
# doc paragraphs reshaped: from 91 to 31
# doc paragraphs reshaped: from 114 to 38
# doc paragraphs reshaped: from 265 to 89
# doc paragraphs reshaped: from 156 to 52
# doc paragraphs reshaped: from 347 to 116
# doc paragraphs reshaped: from 204 to 68
# doc paragraphs reshaped: from 184 to 62
# doc paragraphs reshaped: from 517 to 173
# doc paragraphs reshaped: from 99 to 33
# doc paragraphs reshaped: from 268 to 90
# doc paragraphs reshaped: from 176 to 59
# doc paragraphs reshaped: from 248 to 83
# doc paragraphs reshaped: from 223 to 75
# doc paragraphs reshaped: from 63 to 21
# doc paragraphs reshaped: from 90 to 30
# doc paragraphs reshaped: from 203 to 68
# doc paragraphs reshaped: from 129 to 43

# %%
docs_map[1].keys()
# Out:
# dict_keys(['X', 'y', 'groups', 'X_3_3', 'y_3_3', 'groups_3_3'])

# %%
score_db_man = pd.DataFrame()

# %% [markdown]
# ### Run single example - sequence = 3x paragraph [1:3][4:6]...

# %%
imp.reload(model_utils)
test_percent = 0.2
seed=42
num_splits=10
X_train,y_train,X_test,y_test,test_idx,groups_train,groups_test =  model_utils.split_test_train_docs(docs_map,test_percent,seq_len,step,seed)

# %%
len(y_train),len(y_test)
# Out:
# (4151, 848)

# %% [markdown]
# ### Cross-validate

# %%
imp.reload(model_utils)
score =  model_utils.manual_groups_validate(docs_map,test_percent,seq_len,step,num_splits)
feature_utils.add_score_to_db(score_db_man,"{}_{}_{}_man".format(str(test_percent),seq_len,step),score)
score_db_man
# Out:
# mean_values [0.79513398 0.80080786 0.79555322]
#                   f1   recall  precision
# 0.2_3_3_man 0.795134 0.800808   0.795553

# %% [markdown]
# ### Run single example - sequence = 3x paragraph [1:3][2:5]...

# %%
seq_len=3
step=2
per_par=True
feature_utils.reshape_docs_map_to_seq(docs_map,per_par,seq_len,step)
# Out:
# doc paragraphs reshaped: from 407 to 204
# doc paragraphs reshaped: from 420 to 210
# doc paragraphs reshaped: from 384 to 192
# doc paragraphs reshaped: from 172 to 86
# doc paragraphs reshaped: from 149 to 75
# doc paragraphs reshaped: from 200 to 100
# doc paragraphs reshaped: from 121 to 61
# doc paragraphs reshaped: from 132 to 66
# doc paragraphs reshaped: from 122 to 61
# doc paragraphs reshaped: from 82 to 41
# doc paragraphs reshaped: from 74 to 37
# doc paragraphs reshaped: from 87 to 44
# doc paragraphs reshaped: from 276 to 138
# doc paragraphs reshaped: from 223 to 112
# doc paragraphs reshaped: from 167 to 84
# doc paragraphs reshaped: from 322 to 161
# doc paragraphs reshaped: from 156 to 78
# doc paragraphs reshaped: from 249 to 125
# doc paragraphs reshaped: from 148 to 74
# doc paragraphs reshaped: from 433 to 217
# doc paragraphs reshaped: from 95 to 48
# doc paragraphs reshaped: from 275 to 138
# doc paragraphs reshaped: from 160 to 80
# doc paragraphs reshaped: from 122 to 61
# doc paragraphs reshaped: from 370 to 185
# doc paragraphs reshaped: from 366 to 183
# doc paragraphs reshaped: from 85 to 43
# doc paragraphs reshaped: from 158 to 79
# doc paragraphs reshaped: from 79 to 40
# doc paragraphs reshaped: from 123 to 62
# doc paragraphs reshaped: from 65 to 33
# doc paragraphs reshaped: from 102 to 51
# doc paragraphs reshaped: from 113 to 57
# doc paragraphs reshaped: from 105 to 53
# doc paragraphs reshaped: from 82 to 41
# doc paragraphs reshaped: from 89 to 45
# doc paragraphs reshaped: from 99 to 50
# doc paragraphs reshaped: from 245 to 123
# doc paragraphs reshaped: from 68 to 34
# doc paragraphs reshaped: from 243 to 122
# doc paragraphs reshaped: from 137 to 69
# doc paragraphs reshaped: from 62 to 31
# doc paragraphs reshaped: from 73 to 37
# doc paragraphs reshaped: from 67 to 34
# doc paragraphs reshaped: from 420 to 210
# doc paragraphs reshaped: from 90 to 45
# doc paragraphs reshaped: from 111 to 56
# doc paragraphs reshaped: from 199 to 100
# doc paragraphs reshaped: from 208 to 104
# doc paragraphs reshaped: from 183 to 92
# doc paragraphs reshaped: from 335 to 168
# doc paragraphs reshaped: from 206 to 103
# doc paragraphs reshaped: from 132 to 66
# doc paragraphs reshaped: from 338 to 169
# doc paragraphs reshaped: from 136 to 68
# doc paragraphs reshaped: from 271 to 136
# doc paragraphs reshaped: from 439 to 220
# doc paragraphs reshaped: from 121 to 61
# doc paragraphs reshaped: from 49 to 25
# doc paragraphs reshaped: from 108 to 54
# doc paragraphs reshaped: from 90 to 45
# doc paragraphs reshaped: from 248 to 124
# doc paragraphs reshaped: from 150 to 75
# doc paragraphs reshaped: from 91 to 46
# doc paragraphs reshaped: from 114 to 57
# doc paragraphs reshaped: from 265 to 133
# doc paragraphs reshaped: from 156 to 78
# doc paragraphs reshaped: from 347 to 174
# doc paragraphs reshaped: from 204 to 102
# doc paragraphs reshaped: from 184 to 92
# doc paragraphs reshaped: from 517 to 259
# doc paragraphs reshaped: from 99 to 50
# doc paragraphs reshaped: from 268 to 134
# doc paragraphs reshaped: from 176 to 88
# doc paragraphs reshaped: from 248 to 124
# doc paragraphs reshaped: from 223 to 112
# doc paragraphs reshaped: from 63 to 32
# doc paragraphs reshaped: from 90 to 45
# doc paragraphs reshaped: from 203 to 102
# doc paragraphs reshaped: from 129 to 65

# %%
imp.reload(model_utils)
X_train,y_train,X_test,y_test,test_idx,groups_train,groups_test =  model_utils.split_test_train_docs(docs_map,test_percent,seq_len,step,seed)
score =  model_utils.manual_groups_validate(docs_map,test_percent,seq_len,step,num_splits)
feature_utils.add_score_to_db(score_db_man,"{}_{}_{}_man".format(str(test_percent),seq_len,step),score)
score_db_man
# Out:
# mean_values [0.79203413 0.79833533 0.7930722 ]
#                   f1   recall  precision
# 0.2_3_3_man 0.795134 0.800808   0.795553
# 0.2_3_2_man 0.792034 0.798335   0.793072

# %% [markdown]
# ### Run single example

# %%
seq_len=3
step=3
per_par=True

# %%
X_train,y_train,X_test,y_test,test_idx,groups_train,groups_test =  model_utils.split_test_train_docs(docs_map,test_percent,seq_len,step,seed)

# %%
crf = CRF(
    min_freq = 5,
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True,
    )
crf.fit(X_train, y_train)
y_pred  =  crf.predict(X_test)
labels = list(crf.classes_)
f1 = metrics.flat_f1_score(y_test, y_pred,average='weighted', labels=labels)
recall = metrics.flat_recall_score(y_test, y_pred,average='weighted', labels=labels)
precision = metrics.flat_precision_score(y_test, y_pred,average='weighted', labels=labels)
print ("f1 {}\nrecall {}\nprecition {}".format(f1,recall,precision))
# Out:
# f1 0.809049573674404
# recall 0.8132859486057955
# precition 0.8075455402211509

# %%
y_test[1]
# Out:
# ['is_nar', 'is_nar', 'is_nar', 'is_nar', 'is_nar']

# %% [markdown]
# ### Error analysis

# %%
y_pred_proba = crf.predict_marginals(X_test)

# %%
imp.reload(feature_utils)
feature_utils.get_prediction_report(flatten(y_test),flatten(y_pred),labels)
# Out:
#               precision    recall  f1-score   support
#
#      not_nar       0.85      0.90      0.87      5227
#       is_nar       0.70      0.61      0.65      2089
#
#     accuracy                           0.81      7316
#    macro avg       0.78      0.75      0.76      7316
# weighted avg       0.81      0.81      0.81      7316

# %%
imp.reload(model_utils)
conf_threshold = 0.9
pred_df,_,_ = model_utils.get_info_on_pred(y_pred,y_pred_proba,y_test,groups_test)
pred_df
# Out:
#         seq_idx  idx_in_seq   doc_idx   seq_len    label     pred  pred_proba  \
# 0      0.000000    0.000000 32.000000 25.000000  not_nar  not_nar    0.578161
# 1      0.000000    1.000000 32.000000 25.000000  not_nar  not_nar    0.603149
# 2      0.000000    2.000000 32.000000 25.000000  not_nar  not_nar    0.627281
# 3      0.000000    3.000000 32.000000 25.000000  not_nar  not_nar    0.633655
# 4      0.000000    4.000000 32.000000 25.000000  not_nar  not_nar    0.609484
# ...         ...         ...       ...       ...      ...      ...         ...
# 7311 847.000000    3.000000 30.000000  8.000000  not_nar  not_nar    0.997521
# 7312 847.000000    4.000000 30.000000  8.000000  not_nar  not_nar    0.991256
# 7313 847.000000    5.000000 30.000000  8.000000  not_nar  not_nar    0.972190
# 7314 847.000000    6.000000 30.000000  8.000000  not_nar  not_nar    0.857351
# 7315 847.000000    7.000000 30.000000  8.000000  not_nar  not_nar    0.710364
#
#       correct
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 7311        1
# 7312        1
# 7313        1
# 7314        1
# 7315        1
#
# [7316 rows x 8 columns]

# %%
err_df = pred_df.query("correct == 0")
strong_err = err_df.query("pred_proba > @conf_threshold")
strong_err
# Out:
#         seq_idx  idx_in_seq   doc_idx   seq_len    label     pred  pred_proba  \
# 16     0.000000   16.000000 32.000000 25.000000   is_nar  not_nar    0.900609
# 25     1.000000    0.000000 32.000000  5.000000   is_nar  not_nar    0.998257
# 26     1.000000    1.000000 32.000000  5.000000   is_nar  not_nar    0.995025
# 27     1.000000    2.000000 32.000000  5.000000   is_nar  not_nar    0.974355
# 28     1.000000    3.000000 32.000000  5.000000   is_nar  not_nar    0.941860
# ...         ...         ...       ...       ...      ...      ...         ...
# 6976 821.000000    8.000000 30.000000 10.000000  not_nar   is_nar    0.901796
# 6987 822.000000    9.000000 30.000000 18.000000   is_nar  not_nar    0.976561
# 7249 843.000000    9.000000 30.000000 13.000000   is_nar  not_nar    0.911086
# 7291 846.000000   17.000000 30.000000 34.000000   is_nar  not_nar    0.923907
# 7292 846.000000   18.000000 30.000000 34.000000   is_nar  not_nar    0.921808
#
#       correct
# 16          0
# 25          0
# 26          0
# 27          0
# 28          0
# ...       ...
# 6976        0
# 6987        0
# 7249        0
# 7291        0
# 7292        0
#
# [642 rows x 8 columns]

# %%
corr_df =  pred_df.query("correct == 1")
strong_corr = corr_df.query("pred_proba > @conf_threshold")
strong_corr
# Out:
#         seq_idx  idx_in_seq   doc_idx   seq_len    label     pred  pred_proba  \
# 14     0.000000   14.000000 32.000000 25.000000  not_nar  not_nar    0.952487
# 15     0.000000   15.000000 32.000000 25.000000  not_nar  not_nar    0.944512
# 40     2.000000   10.000000 32.000000 24.000000   is_nar   is_nar    0.959105
# 41     2.000000   11.000000 32.000000 24.000000   is_nar   is_nar    0.984345
# 42     2.000000   12.000000 32.000000 24.000000   is_nar   is_nar    0.986280
# ...         ...         ...       ...       ...      ...      ...         ...
# 7309 847.000000    1.000000 30.000000  8.000000  not_nar  not_nar    0.999949
# 7310 847.000000    2.000000 30.000000  8.000000  not_nar  not_nar    0.999649
# 7311 847.000000    3.000000 30.000000  8.000000  not_nar  not_nar    0.997521
# 7312 847.000000    4.000000 30.000000  8.000000  not_nar  not_nar    0.991256
# 7313 847.000000    5.000000 30.000000  8.000000  not_nar  not_nar    0.972190
#
#       correct
# 14          1
# 15          1
# 40          1
# 41          1
# 42          1
# ...       ...
# 7309        1
# 7310        1
# 7311        1
# 7312        1
# 7313        1
#
# [4736 rows x 8 columns]

# %% [markdown]
# ## Retrive info for all predicted sentenses

# %%
imp.reload(defines)
imp.reload(model_utils)
pred_info_df = model_utils.retrive_predicted_sent(dir_name,pred_df,groups_test,X_test)
pred_info_df.head()
# Out:
#    seq_idx  idx_in_seq   doc_idx   seq_len    label     pred  pred_proba  \
# 0 0.000000    0.000000 32.000000 25.000000  not_nar  not_nar    0.578161
# 1 0.000000    1.000000 32.000000 25.000000  not_nar  not_nar    0.603149
# 2 0.000000    2.000000 32.000000 25.000000  not_nar  not_nar    0.627281
# 3 0.000000    3.000000 32.000000 25.000000  not_nar  not_nar    0.633655
# 4 0.000000    4.000000 32.000000 25.000000  not_nar  not_nar    0.609484
#
#    correct   is_nar  is_client  sent_len  par_idx_in_doc  sent_idx_in_par  \
# 0        1 0.000000   1.000000 27.000000        0.000000         0.000000
# 1        1 0.000000   1.000000 29.000000        0.000000         1.000000
# 2        1 0.000000   1.000000 82.000000        0.000000         2.000000
# 3        1 0.000000   1.000000 15.000000        0.000000         3.000000
# 4        1 0.000000   1.000000 42.000000        0.000000         4.000000
#
#    is_question                                               text     TOKEN
# 0     0.000000                        שאלת אותי ככה בפגישה הקודמת  5.000000
# 1     0.000000                      ↓אוי השארתי את המשקפיים שלי↓   5.000000
# 2     0.000000  נשארתי קצת מבולבלת מהפגישה הקודמת ככה ניסיתי ל... 15.000000
# 3     0.000000                                    לא כל כך הצלחתי  4.000000
# 4     0.000000         חלק הבנתי חלק לא הבנתי מה שאת אומרת לי אהה 10.000000

# %%
pred_info_df
# Out:
#         seq_idx  idx_in_seq   doc_idx   seq_len    label     pred  pred_proba  \
# 0      0.000000    0.000000 32.000000 25.000000  not_nar  not_nar    0.578161
# 1      0.000000    1.000000 32.000000 25.000000  not_nar  not_nar    0.603149
# 2      0.000000    2.000000 32.000000 25.000000  not_nar  not_nar    0.627281
# 3      0.000000    3.000000 32.000000 25.000000  not_nar  not_nar    0.633655
# 4      0.000000    4.000000 32.000000 25.000000  not_nar  not_nar    0.609484
# ...         ...         ...       ...       ...      ...      ...         ...
# 7311 847.000000    3.000000 30.000000  8.000000  not_nar  not_nar    0.997521
# 7312 847.000000    4.000000 30.000000  8.000000  not_nar  not_nar    0.991256
# 7313 847.000000    5.000000 30.000000  8.000000  not_nar  not_nar    0.972190
# 7314 847.000000    6.000000 30.000000  8.000000  not_nar  not_nar    0.857351
# 7315 847.000000    7.000000 30.000000  8.000000  not_nar  not_nar    0.710364
#
#       correct   is_nar  is_client   sent_len  par_idx_in_doc  sent_idx_in_par  \
# 0           1 0.000000   1.000000  27.000000        0.000000         0.000000
# 1           1 0.000000   1.000000  29.000000        0.000000         1.000000
# 2           1 0.000000   1.000000  82.000000        0.000000         2.000000
# 3           1 0.000000   1.000000  15.000000        0.000000         3.000000
# 4           1 0.000000   1.000000  42.000000        0.000000         4.000000
# ...       ...      ...        ...        ...             ...              ...
# 7311        1 0.000000   0.000000  88.000000       81.000000         3.000000
# 7312        1 0.000000   0.000000  14.000000       81.000000         4.000000
# 7313        1 0.000000   0.000000  71.000000       81.000000         5.000000
# 7314        1 0.000000   0.000000 114.000000       81.000000         6.000000
# 7315        1 0.000000   0.000000   6.000000       81.000000         7.000000
#
#       is_question                                               text     TOKEN
# 0        0.000000                        שאלת אותי ככה בפגישה הקודמת  5.000000
# 1        0.000000                      ↓אוי השארתי את המשקפיים שלי↓   5.000000
# 2        0.000000  נשארתי קצת מבולבלת מהפגישה הקודמת ככה ניסיתי ל... 15.000000
# 3        0.000000                                    לא כל כך הצלחתי  4.000000
# 4        0.000000         חלק הבנתי חלק לא הבנתי מה שאת אומרת לי אהה 10.000000
# ...           ...                                                ...       ...
# 7311     0.000000  וכשאת מתארת לי שאת ביום שבת מסתכלת על יום שישי... 18.000000
# 7312     0.000000                                     לאחל לך יותר ש  4.000000
# 7313     0.000000  להרגיש יום אחד שאת עושה את זה ואת מרגישה שזה מ... 16.000000
# 7314     0.000000  שהתחושה הזו הקשה הבאת קשה כאילו להסתכל לאחור ו... 22.000000
# 7315     0.000000                                             50 שנה  2.000000
#
# [7316 rows x 16 columns]

# %%
pred_info_df.to_csv(os.path.join(os.getcwd(),defines.PATH_TO_DFS,dir_name,"1_pred_info.csv"),index=False)

# %% [markdown]
# ### Look at paragraph with wrong prediction

# %%
err_par = pred_info_df.query('correct == 0').groupby(['doc_idx','par_idx_in_doc'])['pred_proba'].agg(np.mean).reset_index()
strong_err_par = err_par.query('pred_proba > @conf_threshold').copy()

# %%
strong_err_idx = pred_info_df.query('correct == 0 and pred_proba > @conf_threshold').index
strong_err_idx
# Out:
# Int64Index([  16,   25,   26,   27,   28,   29,   64,   65,   66,   67,
#             ...
#             6955, 6956, 6957, 6958, 6975, 6976, 6987, 7249, 7291, 7292],
#            dtype='int64', length=642)

# %%
imp.reload(model_utils)
model_utils.print_error_par_text(strong_err_idx,pred_info_df)
# Out:
# ==========
# 32.0 doc: 11 paragraph with error
# doc 32.0 par[2.0]
# Correct labeling:
# מבולבלת ממ.ו ביום מוצאי שבת ככה סימנתי לי איזה תכניות אני רוצה להקליט לשבוע הקרוב כאילו.שזה ממוצאי שבת עד חמישי זה יצא.40 תכניות  שיש תכנית של חצי שעה יש כאלה של יותר ואמרתי כאילו עזבי את המקום ב.ממיר כאילו נגיד אמרנו שיש דברים שאני יכולה למחוק אבל איך אני בכלל.מספיקה לראות את זה או כאילו.XXX ככה נורא הלחיץ אותי וככה כל הזמן הייתי על ה.על האדום של הממיר אבל איכשהו XXX הרבה טלוויזיה ואני גם ברגיל רואה הרבה כנראה פשוט בגלל שעשיתי את זה כזה קדימה זה היה נראה לי.זה הרבה אני לא אומרת שלא אבל זה היה נראה לי יותר.יתר מהרגיל.
# Predicted labeling:
# מבולבלת ממ.ו ביום מוצאי שבת ככה סימנתי לי איזה תכניות אני רוצה להקליט לשבוע הקרוב כאילו.שזה ממוצאי שבת עד חמישי זה יצא.40 תכניות  שיש תכנית של חצי שעה יש כאלה של יותר ואמרתי כאילו עזבי את המקום ב.ממיר כאילו נגיד אמרנו שיש דברים שאני יכולה למחוק אבל איך אני בכלל.מספיקה לראות את זה או כאילו.XXX ככה נורא הלחיץ אותי וככה כל הזמן הייתי על ה.על האדום של הממיר אבל איכשהו XXX הרבה טלוויזיה ואני גם ברגיל רואה הרבה כנראה פשוט בגלל שעשיתי את זה כזה קדימה זה היה נראה לי.זה הרבה אני לא אומרת שלא אבל זה היה נראה לי יותר.יתר מהרגיל.
#
# doc 32.0 par[3.0]
# Correct labeling:
#  את בדרך כלל עושה את זה ככה?.
# Predicted labeling:
#  את בדרך כלל עושה את זה ככה?.
#
# doc 32.0 par[4.0]
# Correct labeling:
# לפעמים אני עושה כמה ימים קדימה ↓XXX שלא אשכח לא לפספס.לא תמיד לפעמים אין לי זמן ↓ וגם כמה שהטלוויזיה נותנת לי היא אמורה לתת שבוע קדימה אבל היא לא תמיד נותנת.לא יודעת יש לה את החישובים שלה .
# Predicted labeling:
# לפעמים אני עושה כמה ימים קדימה ↓XXX שלא אשכח לא לפספס.לא תמיד לפעמים אין לי זמן ↓ וגם כמה שהטלוויזיה נותנת לי היא אמורה לתת שבוע קדימה אבל היא לא תמיד נותנת.לא יודעת יש לה את החישובים שלה .
#
# doc 32.0 par[5.0]
# Correct labeling:
#  וזה הבהיל XXX?.
# Predicted labeling:
#  וזה הבהיל XXX?.
#
# doc 32.0 par[6.0]
# Correct labeling:
# כן כי אמרתי וואי איך אני מספיקה איך אני.זה זה גם אני לא יכולה לדעת מראש בדיוק כמה.אני יכולה להגיד לך בערך כמה שעות זה יהיה לא בדיוק.כאילו יש פרסומות וזה.יש תכניות שאמרתי אוקיי את זה אני רואה XXX אני.מרפרפת לא רואה את הכל.כל מיני כזה.הסתדרתי אבל ככה ב.קצת בלחץ ומה שהחלטתי לעצמי משהו שאני מקווה שאני אעמוד בו סוג מסוים של תכניות עשיתי לי רשימה שאם תוך שבוע אני לא רואה אותם   אני.מעיפה אותם.עכשיו שבוע שעבר היה לי חופש יום רביעי בגלל שלא הסתדר לי יצא כאילו.שהיה לי חופש של 48 שעות.שזה כאילו מצד אחד זה באסה שזה יום רביעי מצד שני זה היה חופש ארוך.כי בדרך כלל זה יוצא החופש של יום שישי אז אני יום חמישי עובדת בערב ושבת בבוקר.אז זה כאילו רק תיום שישי.וככה זה יוצא לי שלישי עבדתי בבוקר וחמישי בערב אז היה לי כאילו  כן אבל בסדר העיקר מבחינתי כרגע זה.לצאת להליכה זה הכי חשוב להוציא תעצמי היה לי קשה הייתי עייפה ואחר כך אמרתי אוקיי אני בסדר נחתי יש לי כוח לצאת להליכה  אז עוד קצת נגרר וזה אז עצם זה שיצאתי זה כבר טוב.אז זהו אז כאילו זה למעשה פעם בשבוע אבל מהפגישה הקודמת זה שתי הליכות.שהחזרתי לעצמי על השבוע הקודם.
י אבל מאיפה זה התחיל כי תמיד הייתי כזאת ש תמיד היה לי נטייה לדחות דברים ותמיד לא אהבתי לנקות כאילו זה תמיד היה אבל זה איכשהו החמיר ואני לא יודעת כאילו להסביר לעצמי למה זה החמיר.נגיד בקטע של ניקיון פעם היה לי בית מאוד קטן אז לנקות אותו זה היה ככה והיו לי פחות חפצים אז פחות מה.שצריך להזיז ככל שזה אז יותר מורכב הנושא של הניקיון.XXX הבית שלי בקיבוץ זה היה ממש ציקצק לנקות אותו גם לא הייתי עושה את זה כל יום אבל זה היה יותר פשוט.כל הזמן זה נהיה יותר ויותר.גם עם הטלוויזיה כל הזמן נהיה יותראבל אני מנסה לחשוב למה.נגיד שגרתי עם הקיבוץ גם לא שהיו באים אליי הרבה אנשים לא שהיה את הקטע הזה שמישהו צריך לבוא והוא לא יכול לבוא כי הבית ממש.לא זוכרת שהיה לי את הסיטואציה הזאת.
#
# ==========
# 65.0 doc: 28 paragraph with error
# doc 65.0 par[11.0]
# Correct labeling:
# בחדר כושר?.
# Predicted labeling:
# בחדר כושר?.
#
# doc 65.0 par[12.0]
# Correct labeling:
# כן.
# Predicted labeling:
# כן.
#
# doc 65.0 par[13.0]
# Correct labeling:
# כן כבר נמאס לי.
# Predicted labeling:
# כן כבר נמאס לי.
#
# doc 65.0 par[14.0]
# Correct labeling:
# כן.
# Predicted labeling:
# כן.
#
# doc 65.0 par[15.0]
# Correct labeling:
# כאילו שם לפחות דיברנו על זה בשבוע שעבר התחושה של החוסר הערכה.פתאום התגלה למנהל חדר כושר.פתאום דברים כאילו רצים ואנשים מדברים על דברים.פגשתי איזה מתעמלת שהיא מפיצה סרטונים שלי כאילו שאנחנו עושים את האימונים.היא ממש יחסי ציבור חבל על הזמן.
# Predicted labeling:
# כאילו שם לפחות דיברנו על זה בשבוע שעבר התחושה של החוסר הערכה.פתאום התגלה למנהל חדר כושר.פתאום דברים כאילו רצים ואנשים מדברים על דברים.פגשתי איזה מתעמלת שהיא מפיצה סרטונים שלי כאילו שאנחנו עושים את האימונים.היא ממש יחסי ציבור חבל על הזמן.
#
# doc 65.0 par[17.0]
# Correct labeling:
# כן יחסי ציבור מהלכת.וזה התגלה לו שהיא כאילו לקוחה של המועדון עושה פתאום אימונים.XXX אימונים כאילו בקבוצות.אז הוא טוען שזה כאילו.הוא פנה בצורה יפה כן?.הוא לא בא בתלונות הוא לא אמר שאני גונב לקוחות אבל הוא אמר שזה ניגוד אינטרסים למכון.אמרתי לו אין פה שום ניגוד אינטרסים.כי קודם כל העניין הזה בא מהלקוח עצמו הלקוח.זאת אומרת היא רצתה לבוא ולעשות איתי את האימון הזה.זה לא שאני באתי והצעתי לה בואי תעזבי את המכון תעשי את האימונים האלה בחוץ.בסוף אנחנו הגענו לאיזה סוג של הבנה.
# Predicted labeling:
# כן יחסי ציבור מהלכת.וזה התגלה לו שהיא כאילו לקוחה של המועדון עושה פתאום אימונים.XXX אימונים כאילו בקבוצות.אז הוא טוען שזה כאילו.הוא פנה בצורה יפה כן?.הוא לא בא בתלונות הוא לא אמר שאני גונב לקוחות אבל הוא אמר שזה ניגוד אינטרסים למכון.אמרתי לו אין פה שום ניגוד אינטרסים.כי קודם כל העניין הזה בא מהלקוח עצמו הלקוח.זאת אומרת היא רצתה לבוא ולעשות איתי את האימון הזה.זה לא שאני באתי והצעתי לה בואי תעזבי את המכון תעשי את האימונים האלה בחוץ.בסוף אנחנו הגענו לאיזה סוג של הבנה.
#
# doc 65.0 par[18.0]
# Correct labeling:
# כן?.
# Predicted labeling:
# כן?.
#
# doc 65.0 par[19.0]
# Correct labeling:
# כן ש אני לא אגלוש כאילו.אני לא אעשה את זה.אני לא שהדבר הזה שעצם הדבר הזה לא יגלוש.זאת אומרת שאני לא אבוא לאנשים.אני גם לא עשיתי את זה.אני לא אבוא לאנשים במכון ואני אעביר אותם כאילו.אליי כלקוחות זה אני בהחלט מסכים.אבל אם אנשים פונים אליי והם רואים.הם רואים פרסום שלי בפייסבוק  הם רוצים כאילו את האוויר.
# Predicted labeling:
# כן ש אני לא אגלוש כאילו.אני לא אעשה את זה.אני לא שהדבר הזה שעצם הדבר הזה לא יגלוש.זאת אומרת שאני לא אבוא לאנשים.אני גם לא עשיתי את זה.אני לא אבוא לאנשים במכון ואני אעביר אותם כאילו.אליי כלקוחות זה אני בהחלט מסכים.אבל אם אנשים פונים אליי והם רואים.הם רואים פרסום שלי בפייסבוק  הם רוצים כאילו את האוויר.
#
# doc 65.0 par[20.0]
# Correct labeling:
# כן אתה גם צריך לדאוג לעצמך.אתה באמת.
# Predicted labeling:
# כן אתה גם צריך לדאוג לעצמך.אתה באמת.
#
# doc 65.0 par[21.0]
# Correct labeling:
# ברור  זה ה.ממ זהו מעניין אותי כאילו מאיפה הדברים האלו צצו.מאיפה זה בא להם למי זה מפריע למי בהנהלה זה מפריע.
# Predicted labeling:
# ברור  זה ה.ממ זהו מעניין אותי כאילו מאיפה הדברים האלו צצו.מאיפה זה בא להם למי זה מפריע למי בהנהלה זה מפריע.
#
# doc 65.0 par[22.0]
# Correct labeling:
#  למישהו ספציפי?.
# Predicted labeling:
#  למישהו ספציפי?.
#
# doc 65.0 par[23.0]
# Correct labeling:
# אני יכול לנחש   ממ בסדר זה יכול להפריע זה לא באמת שזה מפריע לי.
# Predicted labeling:
# אני יכול לנחש   ממ בסדר זה יכול להפריע זה לא באמת שזה מפריע לי.
#
# doc 65.0 par[35.0]
# Correct labeling:
# כן כי אין לי שליטה על זה.
# Predicted labeling:
# כן כי אין לי שליטה על זה.
#
# doc 65.0 par[36.0]
# Correct labeling:
# אז המחשבות הם כאילו סביב למה זה קורה ולמה זה ממשיך לבוא?.
# Predicted labeling:
# אז המחשבות הם כאילו סביב למה זה קורה ולמה זה ממשיך לבוא?.
#
# doc 65.0 par[37.0]
# Correct labeling:
# כן אני לא יודע איך אני יוצא מזה.אין לי מושג.
# Predicted labeling:
# כן אני לא יודע איך אני יוצא מזה.אין לי מושג.
#
# doc 65.0 par[38.0]
# Correct labeling:
# כן דיברנו קצת על זה שזה כאילו לאט שזה.לפעמים לוקח הרבה יותר ממה שאנחנו רוצים מה שאנחנו מוכנים כבר.
# Predicted labeling:
# כן דיברנו קצת על זה שזה כאילו לאט שזה.לפעמים לוקח הרבה יותר ממה שאנחנו רוצים מה שאנחנו מוכנים כבר.
#
# doc 65.0 par[39.0]
# Correct labeling:
# מבחינת זמן?.
# Predicted labeling:
# מבחינת זמן?.
#
# doc 65.0 par[40.0]
# Correct labeling:
# כן כאילו זה קצת כמו שאתה אומר על ה.אתה יודע יש את המקום הזה שאתה רוצה להיות בו ואת המקום שאתה נמצא בו. וכאילו באמת הסיפור הזה של דברים שממשיכים לצוף לנו כי הם אולי כזה.עדיין לא סיימו ל.את העיבוד שלהם.
# Predicted labeling:
# כן כאילו זה קצת כמו שאתה אומר על ה.אתה יודע יש את המקום הזה שאתה רוצה להיות בו ואת המקום שאתה נמצא בו. וכאילו באמת הסיפור הזה של דברים שממשיכים לצוף לנו כי הם אולי כזה.עדיין לא סיימו ל.את העיבוד שלהם.
#
# doc 65.0 par[42.0]
# Correct labeling:
# מה אתה חושב אולי על האפשרות של.לדבר על הנושא כאילו.
# Predicted labeling:
# מה אתה חושב אולי על האפשרות של.לדבר על הנושא כאילו.
#
# doc 65.0 par[43.0]
# Correct labeling:
# איתו אני לא רוצה לדבר.
# Predicted labeling:
# איתו אני לא רוצה לדבר.
#
# doc 65.0 par[44.0]
# Correct labeling:
# לא איתו לא איתו.איתנו או נגיד או עם מי שאתה מרגיש בנוח.כאילו קצת לנסות לראות מה קורה לך שם.כי אני חושבת שזה היה כל כך כאילו כואב ונורא ומאכזב והרבה הרבה דברים כשהוא עזב.וכאילו באיזה מובן קצת נעלת את זה.כאילו אמרת אני לא.אני מוחק אותו הוא כאילו אני לא רוצה להתמודד עם זה.ויכול להיות ש.שיש שם דברים שאתה צריך כאילו לדבר עליהם לחשוב עליהם להתעסק בהם.
# Predicted labeling:
# לא איתו לא איתו.איתנו או נגיד או עם מי שאתה מרגיש בנוח.כאילו קצת לנסות לראות מה קורה לך שם.כי אני חושבת שזה היה כל כך כאילו כואב ונורא ומאכזב והרבה הרבה דברים כשהוא עזב.וכאילו באיזה מובן קצת נעלת את זה.כאילו אמרת אני לא.אני מוחק אותו הוא כאילו אני לא רוצה להתמודד עם זה.ויכול להיות ש.שיש שם דברים שאתה צריך כאילו לדבר עליהם לחשוב עליהם להתעסק בהם.
#
# doc 65.0 par[45.0]
# Correct labeling:
# אני מרגיש שכל פעם שאני מדבר על זה זה כאילו מחזיר אותי לשם.
# Predicted labeling:
# אני מרגיש שכל פעם שאני מדבר על זה זה כאילו מחזיר אותי לשם.
#
# doc 65.0 par[46.0]
# Correct labeling:
# כן?.
# Predicted labeling:
# כן?.
#
# doc 65.0 par[47.0]
# Correct labeling:
# וזה מממ מציק לי וזה לא עושה לי טוב לדבר על זה.
# Predicted labeling:
# וזה מממ מציק לי וזה לא עושה לי טוב לדבר על זה.
#
# doc 65.0 par[48.0]
# Correct labeling:
# כן?.
# Predicted labeling:
# כן?.
#
# doc 65.0 par[49.0]
# Correct labeling:
# כאילו אני מרגיש שאני.צריך להדחיק אבל אני לא יודע אם אני באמת צריך להדחיק.תמיד אנשים נגיד.לא יודע סתם איזה חבר מהמכון ראיתי את.את אל הוא נראה סתם הוא אמר לי כזה ראיתי אותו בחנות שלו והוא נראה ממש ממש טוב היום.וזה כאילו למה אתה אומר לי את זה?.
# Predicted labeling:
# כאילו אני מרגיש שאני.צריך להדחיק אבל אני לא יודע אם אני באמת צריך להדחיק.תמיד אנשים נגיד.לא יודע סתם איזה חבר מהמכון ראיתי את.את אל הוא נראה סתם הוא אמר לי כזה ראיתי אותו בחנות שלו והוא נראה ממש ממש טוב היום.וזה כאילו למה אתה אומר לי את זה?.
#
# doc 65.0 par[50.0]
# Correct labeling:
# מה זה עושה לך שהוא אומר את זה?.כאילו מה זה מעלה אצלך?.
# Predicted labeling:
# מה זה עושה לך שהוא אומר את זה?.כאילו מה זה מעלה אצלך?.
#
# doc 65.0 par[51.0]
# Correct labeling:
# כל מה שקשור אליו עושה לי רע.
# Predicted labeling:
# כל מה שקשור אליו עושה לי רע.
#
# doc 65.0 par[52.0]
# Correct labeling:
# וואו.
# Predicted labeling:
# וואו.
#
# doc 65.0 par[53.0]
# Correct labeling:
# כל מה שקשור ואני אגיד לך את האמת אם אני אשמע משהו שקרה לו רע זה יעשה לי טוב. יש לי איזה שהוא רצון.לנקמה כאילו מממ מצד שני אני גם מנסה לשחרר את עצמי מהמחשבות האלה זה לא מחשבות שהן טובות זה לא אני.
# Predicted labeling:
# כל מה שקשור ואני אגיד לך את האמת אם אני אשמע משהו שקרה לו רע זה יעשה לי טוב. יש לי איזה שהוא רצון.לנקמה כאילו מממ מצד שני אני גם מנסה לשחרר את עצמי מהמחשבות האלה זה לא מחשבות שהן טובות זה לא אני.
#
# doc 65.0 par[83.0]
# Correct labeling:
# עכשיו מעבר לזהנראה לי שגם אני צריך לעשות בדיקות רפואיות לגבי זה.כי עם החלומות האלה וגם עם חלומות אחרים אני לא יודע אם זה מלחץ נפשי או מאיזה שהוא לחץ שיש לי.אני כאילו מתעורר באמצע הלילה.ממ לא יודע עד כמה את קשורה לשאלות על המוח.אה פתאום ה המוח שלי כאילו מפסיק לעבוד ויש לי איזה פרכוס כזה.ו זהו אני כאילו נעצרת לי הנשימה ואני כאילו איך שהוא חוזר ל.וזה מתסכל אותי.זה קורה לי פעם ב.
# Predicted labeling:
# עכשיו מעבר לזהנראה לי שגם אני צריך לעשות בדיקות רפואיות לגבי זה.כי עם החלומות האלה וגם עם חלומות אחרים אני לא יודע אם זה מלחץ נפשי או מאיזה שהוא לחץ שיש לי.אני כאילו מתעורר באמצע הלילה.ממ לא יודע עד כמה את קשורה לשאלות על המוח.אה פתאום ה המוח שלי כאילו מפסיק לעבוד ויש לי איזה פרכוס כזה.ו זהו אני כאילו נעצרת לי הנשימה ואני כאילו איך שהוא חוזר ל.וזה מתסכל אותי.זה קורה לי פעם ב.
#
# doc 65.0 par[305.0]
# Correct labeling:
# כן את יודעת כמה זה עולה?.140 שקל.
# Predicted labeling:
# כן את יודעת כמה זה עולה?.140 שקל.
#
# doc 65.0 par[306.0]
# Correct labeling:
# וואו.
# Predicted labeling:
# וואו.
#
# doc 65.0 par[307.0]
# Correct labeling:
# המסיבה.
# Predicted labeling:
# המסיבה.
#
# doc 65.0 par[308.0]
# Correct labeling:
# רק המסיבה אחת.
# Predicted labeling:
# רק המסיבה אחת.
#
# doc 65.0 par[309.0]
# Correct labeling:
# כמה כסף הם עשו בזה.
# Predicted labeling:
# כמה כסף הם עשו בזה.
#
# ==========
# 4.0 doc: 3 paragraph with error
# doc 4.0 par[3.0]
# Correct labeling:
# אה מורכב מורכב יותר אה היה שבוע עדיין אה כאילו האמת בעיקר שוב זה עדיין אמ.  דיברנו הרי על כל ה זה שממש הרגשתי רע.ב כשחזרתי לארץ מהטיול ואמ.ואני כן מרגיש שאני מצליח איכשהו להתאזן בכל ה סערה הזאת.אמ אני חושב שאני מרגיש יותר טוב משבוע שעבר.כן יש איזה איזשהי הרגשה כזאתי של שיפור.אבל עדיין אה אמ.כאילו הכל אה  הכל נורא חודר אליי.מהר כאילו מאוד מפעיל אצלי דברים אה כאילו שאני מרגיש שאני לא מצליח לשמור על עצמי או אמ.משהו כזה אה וזה והשבוע זה היה בעיקר בעבודה. אמ זה היה.
# Predicted labeling:
# אה מורכב מורכב יותר אה היה שבוע עדיין אה כאילו האמת בעיקר שוב זה עדיין אמ.  דיברנו הרי על כל ה זה שממש הרגשתי רע.ב כשחזרתי לארץ מהטיול ואמ.ואני כן מרגיש שאני מצליח איכשהו להתאזן בכל ה סערה הזאת.אמ אני חושב שאני מרגיש יותר טוב משבוע שעבר.כן יש איזה איזשהי הרגשה כזאתי של שיפור.אבל עדיין אה אמ.כאילו הכל אה  הכל נורא חודר אליי.מהר כאילו מאוד מפעיל אצלי דברים אה כאילו שאני מרגיש שאני לא מצליח לשמור על עצמי או אמ.משהו כזה אה וזה והשבוע זה היה בעיקר בעבודה. אמ זה היה.
#
# doc 4.0 par[5.0]
# Correct labeling:
# אני חושב שבעבודה היה עיקר הקושי. אה פשוט אה אני התחלתי תפקיד חדש לפני אמ.שבועיים ואמ זה בדיוק כשהגעתי מחול אה אז הציעו לי לעבור תפקיד.והיה את המשא ומתן על ה תנאים ועל כל הדברים ובסוף אה אה חתמתי ו ועברתי לתפקיד.עכשיו כשחתמתי על התנאים  היה איזה סעיף אחד.ש החלטתי לא לשאול עליו.בידיעה כאילו – היה איזה סעיף ש החלטה מודעת לא להעיר את השדים עכשיו וכשאני אגיע לזה בקרוב כנראה שעכשיו זה הגיע אני אתמודד עם זה.אה ובעצם הסעיף הזה אומר החלק מההגדרות של התפקיד אז זה גם לעשות כוננויות של לילה.כוננויות של לילה זה אומר אה שבמידה וצריך כאילו אנחנו כמה אנשים בצוות עכשיו אנחנו שלושה.אבל עכשיו יצטרפו הולכים להצטרף עוד שניים זה
# נגיד יש עמותה שקוראים לה כנפיים של קרמבו שמעת עליה?.עמותה שעוזרת לילדים כל מיני ילדים בסיכון כאלה.פניתי דרך אגב למנכלית שלחתי לה מייל שהייתי שמח להשתלב בפעילויות שלהם.היא אמרה שהם לא צריכים כרגע.אז דברים מהסוג הזה עלם או דברים כאלה.שיהיה גם את היכולות ניהול שלי אפילו ככה לעזור להם ב.לגייס כספים שזה גם ככה תחום שאני טוב בו אבל שיהיה לזה איזשהו.איזושהי תרומה לקהילה ערך מוסף.אין לי ספק ש.היה לי חרדה קצת מהנושא של הגיל גם לא יודע ראיתי שאני XXX גם בלי שאני בכלל עושה איזשהו.
#
# doc 29.0 par[101.0]
# Correct labeling:
#  ואתה מרגיש שעם אה אין לזה מספיק ערך מוסף?.
# Predicted labeling:
#  ואתה מרגיש שעם אה אין לזה מספיק ערך מוסף?.
#
# doc 29.0 par[102.0]
# Correct labeling:
# אני לא יודע יש שמה.אני מתלבט עם זה כבר כבר כמה ימים והמערכת שלי לא שקטה.אני לא XXX.אני מחר הולך לשבת מולה ואני.אני אומר לעצמי אנחנו עשינו כמה שיחות בנושא הזה בכל מיני הקשרים גם עכשיו אפילו אבל.הסינדרלה והלכלוכית הזה סיפור הנושא כאן.אז לא להסתנוור מהסינדרלה הזאת להסתכל גם על המציאות מה הולך להיות בעבודה ומה היא בצעם דורשת.כי היא יכולה להבטיח לי הבטחות.
# Predicted labeling:
# אני לא יודע יש שמה.אני מתלבט עם זה כבר כבר כמה ימים והמערכת שלי לא שקטה.אני לא XXX.אני מחר הולך לשבת מולה ואני.אני אומר לעצמי אנחנו עשינו כמה שיחות בנושא הזה בכל מיני הקשרים גם עכשיו אפילו אבל.הסינדרלה והלכלוכית הזה סיפור הנושא כאן.אז לא להסתנוור מהסינדרלה הזאת להסתכל גם על המציאות מה הולך להיות בעבודה ומה היא בצעם דורשת.כי היא יכולה להבטיח לי הבטחות.
#
# doc 29.0 par[103.0]
# Correct labeling:
#  ממה שאתה רואה שהיא דורשת אתה כבר מבין.שזה בעצם לעשות לה קידום אישי ולשווק את הקורסים.
# Predicted labeling:
#  ממה שאתה רואה שהיא דורשת אתה כבר מבין.שזה בעצם לעשות לה קידום אישי ולשווק את הקורסים.
#
# doc 29.0 par[104.0]
# Correct labeling:
# כן אבל יש בזה אולי גם אינטרסים עבורי כי אני כן אוהב XXX שיווק ופרסום XXX לפרסם יכול להיות שהיא כתבה עכשיו ספר דרך אגב כתבתי לה משהו על עצמי הסיפור האישי שלי ואיך השתמשתי בXXX בעצמי.אז אני אהיה שם בספר הזה עם השם שלי צי – מאמן אישי.
# Predicted labeling:
# כן אבל יש בזה אולי גם אינטרסים עבורי כי אני כן אוהב XXX שיווק ופרסום XXX לפרסם יכול להיות שהיא כתבה עכשיו ספר דרך אגב כתבתי לה משהו על עצמי הסיפור האישי שלי ואיך השתמשתי בXXX בעצמי.אז אני אהיה שם בספר הזה עם השם שלי צי – מאמן אישי.
#
# ==========
# 30.0 doc: 5 paragraph with error
# doc 30.0 par[4.0]
# Correct labeling:
רוקחת האחראית לאיזה .לא רק עומס של שעות עבדתי את אותם שעות פחות או יותר אבל נגיד היו מתקשרים אליי.גם כאילו בשעות שאני לא שאני בבית שאני לא בעבודה.התחלתי ללכת עם פלאפון לכל מקום שלא הייתי עושה את זה קודם.נגיד ללכת לקנות עיתון לא הייתי הולכת עם פלאפון כאילו למה מי מת.התחלתי אז היה הרבה עומס אז אני חושבת שאז בערך זה קטע שהפסקתי עם הלסדר של ה.לא חזרתי לזה כנראה אחר כך.

# %%
pred_info_df.iloc[0]
# Out:
# seq_idx                               0.000000
# idx_in_seq                            0.000000
# doc_idx                              32.000000
# seq_len                              25.000000
# label                                  not_nar
# pred                                   not_nar
# pred_proba                            0.578161
# correct                                      1
# is_nar                                0.000000
# is_client                             1.000000
# sent_len                             27.000000
# par_idx_in_doc                        0.000000
# sent_idx_in_par                       0.000000
# is_question                           0.000000
# text               שאלת אותי ככה בפגישה הקודמת
# TOKEN                                 5.000000
# Name: 0, dtype: object

# %%
strong_err_par.sort_values(by='pred_proba',ascending=False,inplace=True)
strong_err_par
# Out:
#       doc_idx  par_idx_in_doc  pred_proba
# 189 29.000000       95.000000    0.999804
# 43  12.000000       58.000000    0.999666
# 46  12.000000       64.000000    0.999531
# 191 29.000000       97.000000    0.999503
# 96  18.000000        9.000000    0.998997
# ..        ...             ...         ...
# 480 79.000000       44.000000    0.906125
# 334 70.000000       66.000000    0.904850
# 107 18.000000       25.000000    0.903994
# 425 72.000000      310.000000    0.902273
# 452 72.000000      359.000000    0.900623
#
# [191 rows x 3 columns]

# %%
from termcolor import colored, cprint

# %%
color_map = {
    1: 'green',
    0: 'red'
}
nar_args = {
    1: ['underline']
}
on_color = {
    'label': 'on_yellow',
    'pred': 'on_cyan'
}

def get_error_par_text(_strong_err_par,pred_info_df):
    strong_err_par = _strong_err_par.copy()
    strong_err_par.sort_values(by=['doc_idx','par_idx_in_doc'],inplace=True)
    for idx,row in strong_err_par.iterrows():
        sentenses = {}
        pred = {}
        label = {}
        par_sent_db = {}
        par_idx = {}
        is_nar = {}
        doc_idx = row['doc_idx']
        par_idx[0] = row['par_idx_in_doc']
        par_sent_db[0] = pred_info_df.query("doc_idx == @doc_idx and par_idx_in_doc== @par_idx[0]")
#         if len(par_sent_db[0].index) < 2: 
#             for neighbor in [-1,1]:
#                     par_idx[neighbor] = par_idx[0]+neighbor
#                     par_sent_db[neighbor] = pred_info_df.query("doc_idx == @doc_idx and par_idx_in_doc== @par_idx[@neighbor]")
        print("==========\n{} doc".format(doc_idx))
        for key in sorted(par_sent_db):
            sentenses[key] = par_sent_db[key]['text'].tolist()
            pred[key]  = par_sent_db[key]['pred'].tolist()
            label[key] = par_sent_db[key]['label'].tolist()
            is_nar[key] = par_sent_db[key]['is_nar'].tolist()
            print("{} par[{}]: confidence {:03f}".format(par_idx[key],key,row['pred_proba']))
            cprint("Correct labeling:",attrs=['bold'])
            for i,sent in enumerate(sentenses[key]):
                cprint(text="{}".format(sentenses[key][i]), on_color=on_color['label'] if label[key][i]=='is_nar'else None,end='.')
            cprint("\nPredicted labeling:",attrs=['bold'])
            for i,sent in enumerate(sentenses[key]):
                cprint(text="{}".format(sentenses[key][i]), on_color=on_color['pred'] if pred[key][i]=='is_nar'else None,end='.')
            print("\n")


        
get_error_par_text(strong_err_par,pred_info_df)
# Out:
# ==========
# 4.0 doc
# 6.0 par[0]: confidence 0.998452
# Correct labeling:
# שאתה אחד מהם.
# Predicted labeling:
# שאתה אחד מהם.
#
# ==========
# 5.0 doc
# 32.0 par[0]: confidence 0.988809
# Correct labeling:
#  אני חושבת שה הדבר המתאגר מסיטואציות XXX זה גם לקבל את זה שלפעמים XXX לא.לא מסתדרים לא מצליחים גם התהליכים שאנחנו עושים כמטפלים לפעמים לא מצליחים.יש מטופלים שזה XXX איתם ויש מטופלים שזה לא עובד איתם.זה גם חלק מהעניין.אבל מעבר לזה אני חושבת שבאמת המקום שבו.זה המקום שדיברת עליו בהרבה סיטואציות אחרות שהפעיל והגיע למקום קשים המקום של הזמנים או.משהו אחר או דברים אחרים שכאילו משהו בדבר הזה נחווה כאיזה פגיעה. ממה זה?.מה הייתה מבחינתך התקשורת XXX?.
# Predicted labeling:
#  אני חושבת שה הדבר המתאגר מסיטואציות XXX זה גם לקבל את זה שלפעמים XXX לא.לא מסתדרים לא מצליחים גם התהליכים שאנחנו עושים כמטפלים לפעמים לא מצליחים.יש מטופלים שזה XXX איתם ויש מטופלים שזה לא עובד איתם.זה גם חלק מהעניין.אבל מעבר לזה אני חושבת שבאמת המקום שבו.זה המקום שדיברת עליו בהרבה סיטואציות אחרות שהפעיל והגיע למקום קשים המקום של הזמנים או.משהו אחר או דברים אחרים שכאילו משהו בדבר הזה נחווה כאיזה פגיעה. ממה זה?.מה הייתה מבחינתך התקשורת XXX?.
#
# ==========
# 5.0 doc
# 53.0 par[0]: confidence 0.958298
# Correct labeling:
# יצא לי לחשוב על זה אחר כך דיברנו על זה פה ואמרתי לעצמי.אוקיי אז היא אמרה משהו לא במקום.בסדר נגיד ש.בסדר זה שאני חושב שזאת הייתה טעות הטעות היית בעיקר הiming להגיד את זה בלא iming ההקשר באיזה הקשר זה נאמר.כי לי זה נחווה כאילו שאת משתמשת בדברים שאני אומר ותופסת עליהם טרמפ בשביל להעביר משהו.אז ההקשר הזה מבחינתי לא היה נכון.אם היית פותחת איתי את הפגישה ואומרת לי אני רוצה לפתוח איתך משהו.אני חווה שמאוד קשה לי לסיים איתך את הפגישות.ואני רוצה שתסתכל על זהמה אתה אומר?.אז הייתי זורם עם זה.אבל אמרת את זה באיזשהו הקשר שהייתי גם ככה מאוד.אז אמרתי רגע היא משתמשת.אחרי זה אמרתי XXX לא עשתה את זה בשביל לפגוע בך.היא רצתה לשקף לך משהו וזה דווקא היה נכון לעשות את זה בהקשר אפשר להסתכל גם מהזווית הזאת.הרי מה הקטע כאילו עלה משהו עכשיו זה בזמן אמת בוא אני אראה לך XXX פה.ומה זה אומר למה אני צריכה.ונניח שהיא באמת עשתה טעותא
#
# ==========
# 12.0 doc
# 24.0 par[0]: confidence 0.989767
# Correct labeling:
# כן.
# Predicted labeling:
# כן.
#
# ==========
# 12.0 doc
# 25.0 par[0]: confidence 0.985066
# Correct labeling:
# כן.
# Predicted labeling:
# כן.
#
# ==========
# 12.0 doc
# 26.0 par[0]: confidence 0.962220
# Correct labeling:
# יש איזה שהיא מחויבות כזאת בקשר ללבוא ללכת לארוחות?.
# Predicted labeling:
# יש איזה שהיא מחויבות כזאת בקשר ללבוא ללכת לארוחות?.
#
# ==========
# 12.0 doc
# 37.0 par[0]: confidence 0.971219
# Correct labeling:
# אה זהו אז פעם שעברה אז לא הלכתי ואחר כך.זה המשיך לי ה.המחשבות האלה שאולי הייתי צריך ללכת שאולי מישהו שם עכשיו כועס או משהו זה.אז הפעם לא ניסיתי להילחם בזה.כאילו פשוט הלכתי.וזהו.
# Predicted labeling:
# אה זהו אז פעם שעברה אז לא הלכתי ואחר כך.זה המשיך לי ה.המחשבות האלה שאולי הייתי צריך ללכת שאולי מישהו שם עכשיו כועס או משהו זה.אז הפעם לא ניסיתי להילחם בזה.כאילו פשוט הלכתי.וזהו.
#
# ==========
# 12.0 doc
# 38.0 par[0]: confidence 0.916520
# Correct labeling:
# מה ההיגיון ש רק מי שרווק חייב לבוא?.
# Predicted labeling:
# מה ההיגיון ש רק מי שרווק חייב לבוא?.
#
# ==========
# 12.0 doc
# 58.0 par[0]: confidence 0.999666
# Correct labeling:
# ממה הם מרוויחים?.
# Predicted labeling:
# ממה הם מרוויחים?.
#
# ==========
# 12.0 doc
# 59.0 par[0]: confidence 0.996706
# Correct labeling:
# ברגע ש שהם באמת מגייסים אותו זאת אומרת אם אחת החברות גייסה דרכם  אז הם מקבלים עמלה סוג של תיווך.
# Predicted labeling:
# ברגע ש שהם באמת מגייסים אותו זאת אומרת אם אחת החברות גייסה דרכם  אז הם מקבלים עמלה סוג של תיווך.
#
# ==========
# 12.0 doc
# 60.0 par[0]: confidence 0.981809
# Correct labeling:
# מהם לא ממך.
# Predicted labeling:
# מהם לא ממך.
#
# ==========
# 12.0 doc
# 64.0 par[0]: confidence 0.999531
# Correct labeling:
# אז לא ברור לימה אתה רוצה?.אתה לא רצית לעבוד שם.
# Predicted labeling:
# אז לא ברור לימה אתה רוצה?.אתה לא רצית לעבוד שם.
#
# ==========
# 12.0 doc
# 81.0 par[0]: confidence 0.962554
# Correct labeling:
# Predicted labeling:
# התגנבו מחשבות שעשית טעות.
# ==========
# 12.0 doc
# 101.0 par[0]: confidence 0.987205
# Correct labeling:
# כן עשיתי טעות עברתי ו.
# Predicted labeling:
# כן עשיתי טעות עברתי ו.
#
# ==========
# 12.0 doc
# 102.0 par[0]: confidence 0.984512
# Correct labeling:
# ואז מה?.
# Predicted labeling:
# ואז מה?.
#
# ==========
# 14.0 doc
# 12.0 par[0]: confidence 0.939497
# Correct labeling:
# רגע באיזה בנק אתה?.
# Predicted labeling:
# רגע באיזה בנק אתה?.
#
# ==========
# 14.0 doc
# 13.0 par[0]: confidence 0.947411
# Correct labeling:
# אני בנק לאומי אבל בנק לאומי רוב הסניפים סגרו את הקופות אז הלכתי היום לבנק טפחות.פעם שעברה הלכתי לבנק דיסקונט.כאילו אני עובר בין סניפים.
# Predicted labeling:
# אני בנק לאומי אבל בנק לאומי רוב הסניפים סגרו את הקופות אז הלכתי היום לבנק טפחות.פעם שעברה הלכתי לבנק דיסקונט.כאילו אני עובר בין סניפים.
#
# ==========
# 14.0 doc
# 14.0 par[0]: confidence 0.958207
# Correct labeling:
# לא אני אני חושב שמה שהוא התכוון להגיד לך שאם אתה בבנק מזרחי כי האוניברסיטה היא בבנק מזרחי אולי הוא חשב.שאתה בבנק מזרחי.
# Predicted labeling:
# לא אני אני חושב שמה שהוא התכוון להגיד לך שאם אתה בבנק מזרחי כי האוניברסיטה היא בבנק מזרחי אולי הוא חשב.שאתה בבנק מזרחי.
#
# ==========
# 14.0 doc
# 15.0 par[0]: confidence 0.959716
# Correct labeling:
# אה טוב לא יודע אני אכנס לבדוק.אבא שלי בנקאי אני פשוט צריך לשאול אותו.
# Predicted labeling:
# אה טוב לא יודע אני אכנס לבדוק.אבא שלי בנקאי אני פשוט צריך לשאול אותו.
#
# ==========
# 14.0 doc
# 16.0 par[0]: confidence 0.957983
# Correct labeling:
# כן שווה לבדוק.
# Predicted labeling:
# כן שווה לבדוק.
#
# ==========
# 14.0 doc
# 17.0 par[0]: confidence 0.934667
# Correct labeling:
# כן רק שאם אני אשאל אותו אז הוא יגיד לי למה אתה צריך לשלם?.ואז אני אצטרך להסביר לו.
# Predicted labeling:
# כן רק שאם אני אשאל אותו אז הוא יגיד לי למה אתה צריך לשלם?.ואז אני אצטרך להסביר לו.
#
# ==========
# 14.0 doc
# 18.0 par[0]: confidence 0.939097
# Correct labeling:
# זהו לא אני חושב שהייתי יודע אם היה אפשר.נשמע לי הגיוני ש.
# Predicted labeling:
# זהו לא אני חושב שהייתי יודע אם היה אפשר.נשמע לי הגיוני ש.
#
# ==========
# 14.0 doc
# 19.0 par[0]: confidence 0.920319
# Correct labeling:
# אמרתי לו אז איך אני מקבל את החותמת אם אני עושה את זה.זה?.אז הוא אמר לי אתה פשוט מדפיס את הספח שמאשר ששילמת.
# Predicted labeling:
# אמרתי לו אז איך אני מקבל את החותמת אם אני עושה את זה.זה?.אז הוא אמר לי אתה פשוט מדפיס את הספח שמאשר ששילמת.
#
# ==========
# 14.0 doc
# 87.0 par[0]: confidence 0.959692
# Correct labeling:
# ו.כאילו הייתי שנה הרי בבית ולמדתי באוניברסיטה.ו הייתי כולי בזה ואז התחלתי לעבוד בהתחלה הייתה ירידה בציונים אבל אחר כך איך שהוא זה התאזן הצלחתי להדביק את הפער פחות או יותר.אבל משהו בחצי שנה האחרונה.אני לא יודע מה היה שם כי ככה זה מרגיש בכל אופן ששם היה השינוי.כאילו המאורע הכי גדול שהיה בשנה בחצי שנה האחרונה זה היה הפיטורים שהיו בעבודה.
# Predicted labeling:
# ו.כאילו הייתי שנה הרי בבית ולמדתי באוניברסיטה.ו הייתי כולי בזה ואז התחלתי לעבוד בהתחלה הייתה ירידה בציונים אבל אחר כך איך שהוא זה התאזן הצלחתי להדביק את הפער פחות או יותר.אבל משהו בחצי שנה האחרונה.אני לא יודע מה היה שם כי ככה זה מרגיש בכל אופן ששם היה השינוי.כאילו המאורע הכי גדול שהיה בשנה בחצי שנה האחרונה זה היה הפיטורים שהיו בעבודה.
#
# ==========
# 14.0 doc
# 109.0 par[0]: confidence 0.978836
# Correct labeling:
# זה ככה.כשאבא שלי בא ואומר לי מתי המבחנים שלך?.אני מיד מרגיש כאילו.אל תדבר איתי על זה עכשיו אני לא רוצה לדבר על זה.כאילו זה נקודה שהוא מצפה ממני עכשיו שאני אגיד לו מתי המבחנים והוא מצפה שאני אצליח במבחנים האלה.וכן פחות או יותר היום אם אני עושה את התואר הזה אז לא בגלל שאני באמת חושב שאני צריך את התואר הזה.
# Predicted labeling:
# זה ככה.כשאבא שלי בא ואומר לי מתי המבחנים שלך?.אני מיד מרגיש כאילו.אל תדבר איתי על זה עכשיו אני לא רוצה לדבר על זה.כאילו זה נקודה שהוא מצפה ממני עכשיו שאני אגיד לו מתי המבחנים והוא מצפה שאני אצליח במבחנים האלה.וכן פחות או יותר היום אם אני עושה את התואר הזה אז לא בגלל שאני באמת חושב שאני צריך את התואר הזה.
#
# ==========
# 15.0 doc
# 21.0 par[0]: confidence 0.955595
# Correct labeling:
# כן כן כי בגלל שאני יוצא מוקדם ביום שני עכשיו בגלל המבחן אז כל השבוע שלי מתקצר.יש לי לימודים ברביעי יש לי לימודים בזה.ו שלישי היה לי לימודים שני יוצא מוקדם.אז המטלות נשארות אותן מטלות.והזמן קצר יותר  ואתמול הייתי צריך לסיים דברים כי דברים שעולים ביום ראשון צריכים להסתיים ביום רביעי.אז ראיתי שאני לא אספיק גם לצאת גם לחזור.אז אמרתי.
# Predicted labeling:
# כן כן כי בגלל שאני יוצא מוקדם ביום שני עכשיו בגלל המבחן אז כל השבוע שלי מתקצר.יש לי לימודים ברביעי יש לי לימודים בזה.ו שלישי היה לי לימודים שני יוצא מוקדם.אז המטלות נשארות אותן מטלות.והזמן קצר יותר  ואתמול הייתי צריך לסיים דברים כי דברים שעולים ביום ראשון צריכים להסתיים ביום רביעי.אז ראיתי שאני לא אספיק גם לצאת גם לחזור.אז אמרתי.
#
#
# ==========
# 18.0 doc
# 14.0 par[0]: confidence 0.947993
# Correct labeling:
# אה החלטת שאתה נכנס לזה.
# Predicted labeling:
# אה החלטת שאתה נכנס לזה.
#
# ==========
# 18.0 doc
# 15.0 par[0]: confidence 0.954505
# Correct labeling:
#  כן  ואחר כך ו  גם XXX איזשהו תהליך מסכם שאמור להוביל אותי באמת ל למספר בודד מאוד של ראיונות אפילו שזה בlevel של XXX זאת אומרת שזה כאילו כבר יותר מפגשים באמת עם אופציה מתוך המקום של הקשרים שלהם וההיכרות שלהם איתי למקום שXXX בתקווה גם אם זה לוקח זמן שיכול להביא אותי באמת לתפקיד משמעותי.אז בין היתר כאילו אני לא יכול להשתחרר מזה זאת אומרת ה עוד פעם גם הרצף התעסוקתי שלי גם ה תהיות המאוד מאוד קשות וXXX אממ חוויה לא טובה שהתלוותה לזה זה באמת גם מערפל לי ברמה הרגשית והאסוציאטיבית מה מה אני XXX בין הדברים ו גם סוג של מטען כבד עכשיו גם יש הרבה פערים ופה XXX זה שאלה אסטרטגית איך איך תוקפים את זה מולם האם זה XXX העובדה שאני הלקוח שלהם זאת אומרת שאני כאילו מעסיק אותם או שוכר את שירותיהם האם אני יכול להיות כנה ובטוח לגמרי מתוך רצון שבאמת הייחודיות שלי או הצרכים שלי או המה שוואטאבר באמת יהיה לזה את הערך המוסף הXXX שכיום זה הפך כאילו גם סוג של אתגר עצם המציאה אבל גם לא רק בהקשר הזה אל ברמת ה היכולת שלי להנות ממנו ולהיות משמעותי בו.
# Predicted labeling:
#  כן  ואחר כך ו  גם XXX איזשהו תהליך מסכם שאמור להוביל אותי באמת ל למספר בודד מאוד של ראיונות אפילו שזה בlevel של XXX זאת אומרת שזה כאילו כבר יותר מפגשים באמת עם אופציה מתוך המקום של הקשרים שלהם וההיכרות שלהם איתי למקום שXXX בתקווה גם אם זה לוקח זמן שיכול להביא אותי באמת לתפקיד משמעותי.אז בין היתר כאילו אני לא יכול להשתחרר מזה זאת אומרת ה עוד פעם גם הרצף התעסוקתי שלי גם ה תהיות המאוד מאוד קשות וXXX אממ חוויה לא טובה שהתלוותה לזה זה באמת גם מערפל לי ברמה הרגשית והאסוציאטיבית מה מה אני XXX בין הדברים ו גם סוג של מטען כבד עכשיו גם יש הרבה פערים ופה XXX זה שאלה אסטרטגית איך איך תוקפים את זה מולם האם זה XXX העובדה שאני הלקוח שלהם זאת אומרת שאני כאילו מעסיק אותם או שוכר את שירותיהם האם אני יכול להיות כנה ובטוח לגמרי מתוך רצון שבאמת הייחודיות שלי או הצרכים שלי או המה שוואטאבר באמת יהיה לזה את הערך המוסף הXXX שכיום זה הפך כאילו גם סוג של אתגר עצם המציאה אבל גם לא רק בהקשר הזה אל ברמת ה היכולת שלי להנות ממנו ולהיות משמעותי בו.
#
# ==========
# 18.0 doc
# 25.0 par[0]: confidence 0.903994
# Correct labeling:
שנת אבטלה התחלתי שנת אבטלה מחדש עם זכאות מלאה וברמה מאוד מאוד נמוכה אפילו לא יודע כמה זה זה סדר גודל של בין 40005000 שקל.אממ  בגלל השכר הנמוך בביטוח לאומי.עכשיו לי נפלה התודעה הבנה מאוד ברורה שאני לא יכול ללכת עוד פעם לעבודות כאלה כי אם חשבתי שעבודות כאלה יפתרו לי את הבעיה אז הבנתי שממש לא כי שהן ממש לא.זאת אומרת זה לא העניין של ה יש גם את העניין של היכולת אבל זה לא העניין של היכולת זה העניין של הבאמת לפתור היבטים רגשיים והיבטים של באמת של אה בין אישיים וכו.ו את הקורס עשיתי בידיעה שאני לא יודע מה קורה איתי אבל אם אני צריך מחר בבוקר מיד לעבוד אז אז יש לי משהו שאני יכול להתחיל לעבוד.ואז היה דסקוס סביב העניין הזה וזה גם עלה באופציה של להיות איזשהו ללמוד את זה ואז להתחיל ללמוד עיצוב תעשייתי וכאילו להתפתח לכיוון של עצמאי בעניין הזה.
#
# ==========
# 18.0 doc
# 58.0 par[0]: confidence 0.963816
# Correct labeling:
# סיימתם את המפגשים?.
# Predicted labeling:
# סיימתם את המפגשים?.
#
# ==========
# 18.0 doc
# 59.0 par[0]: confidence 0.961056
# Correct labeling:
#  כן.
# Predicted labeling:
#  כן.
#
# ==========
# 18.0 doc
# 60.0 par[0]: confidence 0.942764
# Correct labeling:
# עכשיו הוא צריך לרשום את ההערכה?.
# Predicted labeling:
# עכשיו הוא צריך לרשום את ההערכה?.
#
# ==========
# 28.0 doc
# 21.0 par[0]: confidence 0.960702
# Correct labeling:
# שאני מתחיל להסביר יותר מדי XXX כאילו להביא איזה.XXX תיק של עורך דין כזה מלא.ראיות ועניינים וטקטקטק.
# Predicted labeling:
# שאני מתחיל להסביר יותר מדי XXX כאילו להביא איזה.XXX תיק של עורך דין כזה מלא.ראיות ועניינים וטקטקטק.
#
# ==========
# 28.0 doc
# 22.0 par[0]: confidence 0.913871
# Correct labeling:
#  ואז מה לא עובר לך XXX התיק?.
# Predicted labeling:
#  ואז מה לא עובר לך XXX התיק?.
#
# ==========
# 28.0 doc
# 24.0 par[0]: confidence 0.950811
# Correct labeling:
#  אבל כשאתה עושה את זה מה לא עובר?.
# Predicted labeling:
#  אבל כשאתה עושה את זה מה לא עובר?.
#
# ==========
# 28.0 doc
# 25.0 par[0]: confidence 0.945702
# Correct labeling:
# מה זאת אומרת מה לא עובר?.
# Predicted labeling:
# מה זאת אומרת מה לא עובר?.
#
# ==========
# 28.0 doc
# 26.0 par[0]: confidence 0.931847
# Correct labeling:
#  אמרת שאתה מרגיש שאתה כאילו לא מצליח להעביר את זה.
# Predicted labeling:
#  אמרת שאתה מרגיש שאתה כאילו לא מצליח להעביר את זה.
#
# ==========
# 28.0 doc
# 27.0 par[0]: confidence 0.956220
# Correct labeling:
# אני לא מצליח להעביר את הרגש אולי או את התחושה.
# Predicted labeling:
# אני לא מצליח להעביר את הרגש אולי או את התחושה.
#
# ==========
# 28.0 doc
# 28.0 par[0]: confidence 0.952790
# Correct labeling:
#  מה שלא עובר זה הXXX סביבו הרגש שנמצא איתך.
# Predicted labeling:
#  מה שלא עובר זה הXXX סביבו הרגש שנמצא איתך.
# ==========
# 28.0 doc
# 29.0 par[0]: confidence 0.937219
# Correct labeling:
# כאילו אולי אחד הדברים שאני מנסה לעבוד עליהם זה לדבר קצר וענייני ולהעביר משהו כמסר מרכזי ואני לא עושה את זה.
# Predicted labeling:
# כאילו אולי אחד הדברים שאני מנסה לעבוד עליהם זה לדבר קצר וענייני ולהעביר משהו כמסר מרכזי ואני לא עושה את זה.
#
# ==========
# 28.0 doc
# 30.0 par[0]: confidence 0.923813
# Correct labeling:
#  מה המסר המרכזי של הסיפור עם יל?.
# Predicted labeling:
#  מה המסר המרכזי של הסיפור עם יל?.
#
# ==========
# 28.0 doc
# 33.0 par[0]: confidence 0.996393
# Correct labeling:
# אני חושבת שמה שעמד זה שהיא תרגיש לא תרגיש נוח.
# Predicted labeling:
# אני חושבת שמה שעמד זה שהיא תרגיש לא תרגיש נוח.
#
# ==========
# 28.0 doc
# 34.0 par[0]: confidence 0.993621
# Correct labeling:
#  ממה היא חששה לדעתך?.
# Predicted labeling:
#  ממה היא חששה לדעתך?.
#
# ==========
# 28.0 doc
# 36.0 par[0]: confidence 0.996644
# Correct labeling:
#  אתה חושב שיש משהו בקשר שלכם שהוביל אותה להיות זהירה עם ההכנסה שלך לקבוצה?.
# Predicted labeling:
#  אתה חושב שיש משהו בקשר שלכם שהוביל אותה להיות זהירה עם ההכנסה שלך לקבוצה?.
#
# ==========
# 28.0 doc
# 37.0 par[0]: confidence 0.912526
# Correct labeling:
# שאלה מצוינת אני לא יודע.אני סובבתי את זה מכל הזוויות כרגע אני בחרתי להתרחק אני מאוד פגוע מאוד כועס.דרך אגב ביום חמישי פוצצתי לה את היום הולדת אמרתי לה שאני לא מגיע שזה מאוד העליב אותי אני לא מגיע ושתחגוג עם החברים שלי.כמובן שהאירוע התבטל.מה שרק חיזק את זה שזה לא שהיא הפרידה שתי קבוצות כי אם אני לא מגיע לשם אין יום הולדת אין.אחותי לא תבוא בלעדי גי בטח שלא יבוא בלעדי.אן לא יבוא אם אני לא יבוא וסת ומב לא באו תאם אן לא בא.אז לא היום הולדת הזה לא התקיים.אני הרגשתי שאני.הקטע שגם תקשרתי את זה לפני זה ואמרתי את הרגשות.ואז היא אמרה לי אוקיי אז תשמע אם אתה רוצה אז תבוא יום שישי אני אשמח לראות אותך.מה זה אם אתה רוצה אז תבוא?.אם אתה רוצה אז תבוא?.מה זה הדבר הזה.את לא רוצה שאני אבוא?.אם את רוצה אז תגידי לי XXX אני מדבר ואני.לא רוצה לדבר מתוך כעס אני כרגע.עד שאני נרגע אני לא.אבל זה סתם.
# Predicted labeling:
# אני רוצה אותה יותר קרוב אבל יותר רחוק כאילו במקביל.אני לא יודע איך להסביר את זה.כאילו מצד אחד כאילו פתחתי לה דלת זה ברמה שהיינו באילת וכאילו.מה זה רציתי לא לשמוע ממנה.עכשיו כאילו ראיתי איך משתמשת ב.לא יודע לא בא לי כי כל שיחה איתה זה שיחת נפש וחפירות XXX ואיפה זה פוגש אותי.ולא בא לי שיחות כאלה בא לי ליהנות עכשיו בא לי שיחות כאלה סתם.לא בא לי שיחות כאלויש לי פה את השיחות שאני חופר וזהו לא בא לי.היא לא מטפלת שלי עכשיו.והיא קצת שמה את עצמה במקום של מטפלת אבל עבורי היה איזה קטע שדיברנו ואני מדבר איתה קצר היה לי איזה מסר להעביר לה ורציתי לסיים את השיחה וראיתי איך היא תופסת אותי רגע אבל מה שלומך?.היא הייתה עם כל ההקשבה ואמפתיה כמו איזה מטפלת עכשיו זה כאילו זה כאיל והקשבה אבל ממקום לא נקי.זה עבר מניפולטיבי קצת XXX.
#
# ==========
# 28.0 doc
# 105.0 par[0]: confidence 0.931557
# Correct labeling:
# הנה יש לי מערכת אני יכול לתת לך דוגמאות כן.כמו שן למשל ש.זרקתי לו איזה מילה אנחנו אסטרולוגית כרגע אנחנו בזמן של נסיגה מרקורי לא משנה זה כאילו תקופה ש.מכירה את זה?.
# Predicted labeling:
# הנה יש לי מערכת אני יכול לתת לך דוגמאות כן.כמו שן למשל ש.זרקתי לו איזה מילה אנחנו אסטרולוגית כרגע אנחנו בזמן של נסיגה מרקורי לא משנה זה כאילו תקופה ש.מכירה את זה?.
#
# ==========
# 28.0 doc
# 111.0 par[0]: confidence 0.940290
# Correct labeling:
# כן אני לא יודע גם.
# Predicted labeling:
# כן אני לא יודע גם.
#
# ==========
# 28.0 doc
# 130.0 par[0]: confidence 0.926542
# Correct labeling:
#  איזה תיק אתה תופר לה?.
# Predicted labeling:
#  איזה תיק אתה תופר לה?.
#
# ==========
# 29.0 doc
# 46.0 par[0]: confidence 0.954220
# Correct labeling:
# כן שלא באתי ואני אומר לך אה אני הייתי מאוד ברור אני XXX מחויבות איזה מחויבות בכלל את מדברת עכשיו יש לי שיחות על מחויבות אני יודע מאוד קשה לי להתחייב.אפילו בזוגיות שלי סידרתי איתו שאני לא אהיה לגמרי מחויבשהוא לא יגור איתי ו.יש לי יחסי אהבהשנאה עם מחויבות.
# Predicted labeling:
# כן שלא באתי ואני אומר לך אה אני הייתי מאוד ברור אני XXX מחויבות איזה מחויבות בכלל את מדברת עכשיו יש לי שיחות על מחויבות אני יודע מאוד קשה לי להתחייב.אפילו בזוגיות שלי סידרתי איתו שאני לא אהיה לגמרי מחויבשהוא לא יגור איתי ו.יש לי יחסי אהבהשנאה עם מחויבות.
#
# ==========
# 29.0 doc
# 59.0 par[0]: confidence 0.914834
# Correct labeling:
#  שפחדת שאני לא אעמוד בהבטחה.
# Predicted labeling:
#  שפחדת שאני לא אעמוד בהבטחה.
#
# ==========
# 29.0 doc
# 60.0 par[0]: confidence 0.941249
# Correct labeling:
# כן אבל זה לא עלייך זה באופן כללי.וגם אה כאילו כל פעם שהיו לו הבטחות הם לא התקיימו במציאות.אם אני עכשיו אספר לך גם תקשרתי את זה איתה אני מספר לך עכשיו כאילו כל מה שדיברנו.אתה XXX ואתה הולך לזה ואני הולכת להעביר לך אימונים ואתה תהיה חלק ואתה תהיה שותף.וכלום לא קרה מזה במציאות.במציאות מה שעשיתי זה לשבת ולעשות טלמרקטינג.
# Predicted labeling:
# כן אבל זה לא עלייך זה באופן כללי.וגם אה כאילו כל פעם שהיו לו הבטחות הם לא התקיימו במציאות.אם אני עכשיו אספר לך גם תקשרתי את זה איתה אני מספר לך עכשיו כאילו כל מה שדיברנו.אתה XXX ואתה הולך לזה ואני הולכת להעביר לך אימונים ואתה תהיה חלק ואתה תהיה שותף.וכלום לא קרה מזה במציאות.במציאות מה שעשיתי זה לשבת ולעשות טלמרקטינג.
#
# ==========
# 29.0 doc
# 69.0 par[0]: confidence 0.917923
# Correct labeling:
#  הזכרת את זה הזכר את הגניבות הזכרת את התחושה שלוקחים לך.
# Predicted labeling:
#  הזכרת את זה הזכר את הגניבות הזכרת את התחושה שלוקחים לך.
# ==========
# 29.0 doc
# 88.0 par[0]: confidence 0.928544
# Correct labeling:
# אני פעם אחת אמרתי לאמא שלי את זוכרת את המכות שהייתם מרביצים לי?.שאת הייתוהיא התחילה לקבל ויברציה בגוף והיא לא זוכרת כלום מזה .אבל הגוף לא משקר.זה מה שאני אומר הגוף לא משקר לא יעזור.כי אם היית נינוחה עם זה אם היא הייתה נינוחה אז היא לא הייתה מקבלת כאלה את רואה שלא נוח לך בגוף מקבלת ויברציות כאלה.
# Predicted labeling:
# אני פעם אחת אמרתי לאמא שלי את זוכרת את המכות שהייתם מרביצים לי?.שאת הייתוהיא התחילה לקבל ויברציה בגוף והיא לא זוכרת כלום מזה .אבל הגוף לא משקר.זה מה שאני אומר הגוף לא משקר לא יעזור.כי אם היית נינוחה עם זה אם היא הייתה נינוחה אז היא לא הייתה מקבלת כאלה את רואה שלא נוח לך בגוף מקבלת ויברציות כאלה.
#
# ==========
# 29.0 doc
# 94.0 par[0]: confidence 0.992637
# Correct labeling:
# בפועל המשרה זה בדיוק מה ששאלתי אותה מה זה אומר איך נראה היום שלי ממ בלי כל ההבטחות מה זה אומר במציאות?.מגיע יום עבודה היא רוצה שאני אעשה לה את ההרשמות שזה אומר תכלס לעשות טלמרקטינג להתקשר ללידים ולרשום אותם.אני עושה את זה עכשיו כבר כמה שבועות.עכשיו זה אחלה כסף וזה נוח לי כאילו.XXX 3 שנים כבר ניהלתי טלמרקטינג XXX לעשות את זה בעצמי לא יודע אם בא לי.ולעשות לה את כל השיווק.שיתופי פעולה שיווק בפייסבוק שיווק בזה.כאילו המטרה להביא לידים ואז למכור להם.משהו כזה ולהיות הזה שמגיש לה את הקנקן מים.מצד שני כאילו נורא בא לי לחזור לאימון אני מאוד אוהב את המקום של אימון.אני חושב ש.עמדה ש יש השפעה.
# Predicted labeling:
# זה מחזיר עוד פעם לחברות האלה של סלולר.הוט יס ואלה.זה בטוח לא לא בא לי.סבלתי מזה ממש.XXX תפקיד הבא שלי איזשהו ערך מוסף.אני חושב שכאילו.אני אוהב את המקום של לנהל.לא לא רק מהמקום של הדרגות על הכתפיים כל מה שדיברנו כאן.כל מה שדיברנו כאן המקומות האישיים שלי.אני חושב ש.שניהול בשבילי זה משהו שהוא גם אתמול כתבה מישהי בפייסבוק אחת מהנציגות שלי מאולגובס כזה כתבה לי על הקיראתה היית המנהל הכי טוב שלי אני מאוד מתגעגעת לתקופה שהיית מנהל אתה בן אדם חכם ויוצא דופן שינית לי את החיים.אז כאילו קיבלתי משבצת של להיות מנהל אבל אני בטוח שהייתה שם השפעה גם.מעבר ל אם אני מסתכל נגיד לאורך הדרך מי האנשים שהשפיעו עליי אז חלק מהם זה גם אנשים שהם היו מנהלים שלי שהשפיעו עליי.נגיד תר מאולגובס היה מנהל אבל.היה בו משהו שהשפיע עליי XXX כאדם.
#
# ==========
# 29.0 doc
# 99.0 par[0]: confidence 0.990351
# Correct labeling:
#  ו באיזה מקומות אתה רואה את עצמך XXX?.
# Predicted labeling:
#  ו באיזה מקומות אתה רואה את עצמך XXX?.
#
# ==========
# 29.0 doc
# 101.0 par[0]: confidence 0.991992
# Correct labeling:
#  ואתה מרגיש שעם אה אין לזה מספיק ערך מוסף?.
# Predicted labeling:
#  ואתה מרגיש שעם אה אין לזה מספיק ערך מוסף?.
#
# ==========
# 29.0 doc
# 102.0 par[0]: confidence 0.963985
# Correct labeling:
# אני לא יודע יש שמה.אני מתלבט עם זה כבר כבר כמה ימים והמערכת שלי לא שקטה.אני לא XXX.אני מחר הולך לשבת מולה ואני.אני אומר לעצמי אנחנו עשינו כמה שיחות בנושא הזה בכל מיני הקשרים גם עכשיו אפילו אבל.הסינדרלה והלכלוכית הזה סיפור הנושא כאן.אז לא להסתנוור מהסינדרלה הזאת להסתכל גם על המציאות מה הולך להיות בעבודה ומה היא בצעם דורשת.כי היא יכולה להבטיח לי הבטחות.
# Predicted labeling:
# ...
#
# ==========
# 70.0 doc
# 77.0 par[0]: confidence 0.933709
# Correct labeling:
# אבל אתה אבא.
# Predicted labeling:
# אבל אתה אבא.
#
# ==========
# 70.0 doc
# 78.0 par[0]: confidence 0.917765
# Correct labeling:
# אבא.
# Predicted labeling:
# אבא.
#
# ==========
# 70.0 doc
# 79.0 par[0]: confidence 0.950457
# Correct labeling:
# אז היא אמרה שאתה לא מתאים אבל אתה אבא.
# Predicted labeling:
# אז היא אמרה שאתה לא מתאים אבל אתה אבא.
#
# ==========
# 70.0 doc
# 95.0 par[0]: confidence 0.930608
# Correct labeling:
# אתה יודע צי אני מרגיש שקצת ככה הדברים מתערבבים כי באת והתחלת לספר על הקשר עם גן  XXX וככה נראה לי שהכל מתערבב לידי איזשהו מאורע מאוד מפחיד.
# Predicted labeling:
# אתה יודע צי אני מרגיש שקצת ככה הדברים מתערבבים כי באת והתחלת לספר על הקשר עם גן  XXX וככה נראה לי שהכל מתערבב לידי איזשהו מאורע מאוד מפחיד.
# ==========
# 70.0 doc
# 148.0 par[0]: confidence 0.932911
# Correct labeling:
# אה  אושר חיבוק אה  אה  אה זאת אומרת אה אני חושב שאני מסתכל יכול להיות שלפעמים אני גם מסתכל על קשר אחד שהיה לי בעבר שהייתה לי שאני אה.כמה חודשים אישה אחת XXX שהיינו XXX הייתה ההיילייט של הערב שהיא קצת XXX לפני גן לא חשוב גם גן היה כיפי מאוד היה היה גיל אחר תקופה אחרת.
# Predicted labeling:
# אה  אושר חיבוק אה  אה  אה זאת אומרת אה אני חושב שאני מסתכל יכול להיות שלפעמים אני גם מסתכל על קשר אחד שהיה לי בעבר שהייתה לי שאני אה.כמה חודשים אישה אחת XXX שהיינו XXX הייתה ההיילייט של הערב שהיא קצת XXX לפני גן לא חשוב גם גן היה כיפי מאוד היה היה גיל אחר תקופה אחרת.
#
# ==========
# 72.0 doc
# 11.0 par[0]: confidence 0.934790
# Correct labeling:
# אני לא זוכר מתי זה קרה.כאילו את יודעת אני מעביר חוגים אני מעביר זה.ובאמת ב אני מוציא מעצמי כאילו מלא.תעצומות של זה לא אנרגיה זה כאילו כוח רצון כדי להעביר את זה.
# Predicted labeling:
# אני לא זוכר מתי זה קרה.כאילו את יודעת אני מעביר חוגים אני מעביר זה.ובאמת ב אני מוציא מעצמי כאילו מלא.תעצומות של זה לא אנרגיה זה כאילו כוח רצון כדי להעביר את זה.
#
# ==========
# 72.0 doc
# 12.0 par[0]: confidence 0.973735
# Correct labeling:
# כן.
# Predicted labeling:
# כן.
#
# ==========
# 72.0 doc
# 13.0 par[0]: confidence 0.970469
# Correct labeling:
#  שבוע הבא זה נגמר.
# Predicted labeling:
#  שבוע הבא זה נגמר.
#
# ==========
# 72.0 doc
# 14.0 par[0]: confidence 0.948399
# Correct labeling:
# זה מחליש אותך.
# Predicted labeling:
# זה מחליש אותך.
#
# ==========
# 72.0 doc
# 78.0 par[0]: confidence 0.941231
# Correct labeling:
# בטח זה מאוד חשוב.
# Predicted labeling:
# בטח זה מאוד חשוב.
#
# ==========
# 72.0 doc
# 79.0 par[0]: confidence 0.933046
# Correct labeling:
# ממש.
# Predicted labeling:
# ממש.
#
# ==========
# 72.0 doc
# 80.0 par[0]: confidence 0.916813
# Correct labeling:
# מה שינית?.
# Predicted labeling:
# מה שינית?.
#
# ==========
# 72.0 doc
# 84.0 par[0]: confidence 0.940002
# Correct labeling:
# אהה כן עשית משהו רציני יותר אתה מתכוון משהו שהוא יותר.
# Predicted labeling:
# אהה כן עשית משהו רציני יותר אתה מתכוון משהו שהוא יותר.
#
# ==========
# 72.0 doc
# 85.0 par[0]: confidence 0.929782
# Correct labeling:
# כן פחות להדגיש את עצמי יותר בקטע של מה נעשה.
# Predicted labeling:
# כן פחות להדגיש את עצמי יותר בקטע של מה נעשה.
#
# ==========
# 72.0 doc
# 99.0 par[0]: confidence 0.954634
# Correct labeling:
# עזבי אני יכול לתת לך דוגמא.יש לי חבר ממש קרוב בן 48  הוא טייל בעולם וזה ועכשיו הוא כבר 7 שנים בחדר כושר.מגיל 40 ואני אני רואה אותו מאושר כן?.הוא מבסוט אבל אני לא יכול להיות מאושר בסיטואציה הזאת שלו.
# Predicted labeling:
# עזבי אני יכול לתת לך דוגמא.יש לי חבר ממש קרוב בן 48  הוא טייל בעולם וזה ועכשיו הוא כבר 7 שנים בחדר כושר.מגיל 40 ואני אני רואה אותו מאושר כן?.הוא מבסוט אבל אני לא יכול להיות מאושר בסיטואציה הזאת שלו.
#
# ==========
# 72.0 doc
# 100.0 par[0]: confidence 0.958945
# Correct labeling:
# למה?.
# Predicted labeling:
# למה?.
#
# ==========
# 72.0 doc
# 103.0 par[0]: confidence 0.954633
# Correct labeling:
# אז כמה קליינטורה היה לי בסוף השבוע.אני אומר לעצמי מה?.בגיל 48?.אני לא רוצה להיות ככה.
# Predicted labeling:
# אז כמה קליינטורה היה לי בסוף השבוע.אני אומר לעצמי מה?.בגיל 48?.אני לא רוצה להיות ככה.
#
# ==========
# 72.0 doc
# 104.0 par[0]: confidence 0.996210
# Correct labeling:
# אבל מה מה אתה מרגיש על זה?.שזה מה מה זה אומר להיות שם?.
# Predicted labeling:
# אבל מה מה אתה מרגיש על זה?.שזה מה מה זה אומר להיות שם?.
#
# ==========
# 72.0 doc
# 105.0 par[0]: confidence 0.978317
# Correct labeling:
# אני מרגיש שהוא עדיין.כאילו בן 48 הוא גם נראה בן 48 והוא עדין מתנהג בצורה ילדותית כזאתי.
# Predicted labeling:
# אני מרגיש שהוא עדיין.כאילו בן 48 הוא גם נראה בן 48 והוא עדין מתנהג בצורה ילדותית כזאתי.
#
# ==========
# 72.0 doc
# 109.0 par[0]: confidence 0.982801
# Correct labeling:
# כן.
# Predicted labeling:
# כן.
#
# ==========
# 72.0 doc
# 110.0 par[0]: confidence 0.985717
# Correct labeling:
# אז גם יש לך כאילו אישור מהמציאות שזה לא משהו שאתה רוצה.
# Predicted labeling:
# אז גם יש לך כאילו אישור מהמציאות שזה לא משהו שאתה רוצה.
#
# ==========
# 72.0 doc
# 111.0 par[0]: confidence 0.947150
# Correct labeling:
# בדיוק ו הוא רוצה שאני אצא משם.הוא כאילו דואג לי.אבל אנחנו חברים כאלה טובים שהוא רוצה שאני אצא משם.
# Predicted labeling:
# בדיוק ו הוא רוצה שאני אצא משם.הוא כאילו דואג לי.אבל אנחנו חברים כאלה טובים שהוא רוצה שאני אצא משם.
#
# ==========
# 72.0 doc
# 112.0 par[0]: confidence 0.991659
# Correct labeling:
# גם אתה רוצה לצאת משם.
# Predicted labeling:
# גם אתה רוצה לצאת משם.
#
# ==========
# 72.0 doc
# 113.0 par[0]: confidence 0.996290
# Correct labeling:
# כן אבל כשמישהו אומר לך אני רוצה שתצא מפה ולא בקטע של.אני לא חבר שלך לא בא לי להסתכל עליך.זה באמת בקטע של דאגה בקטע של. הוא רואה שאני כבר.גם מיציתי וגם הוא רואה שזה בזבוז של זמן.זה סבבה כסף אפשר לחיות.חיים סבבה החיים אבל משעממים.
# Predicted labeling:
# כן אבל כשמישהו אומר לך אני רוצה שתצא מפה ולא בקטע של.אני לא חבר שלך לא בא לי להסתכל עליך.זה באמת בקטע של דאגה בקטע של. הוא רואה שאני כבר.גם מיציתי וגם הוא רואה שזה בזבוז של זמן.זה סבבה כסף אפשר לחיות.חיים סבבה החיים אבל משעממים.
#
# ==========
# 72.0 doc
# 125.0 par[0]: confidence 0.946587
# Correct labeling:
# כן בדיוק אמרתי לעצמי.סתם התקלחתי אמרתי מצד אחד יש לי את הפחד הזה.גם להיות זוטר.גם להכיר להגיע למקום שאני לא מכיר.דיברנו על זה.גם  לעזוב את הכל לרדת.מצד שני זה להתחיל מחדש. כן.
# Predicted labeling:
# כן בדיוק אמרתי לעצמי.סתם התקלחתי אמרתי מצד אחד יש לי את הפחד הזה.גם להיות זוטר.גם להכיר להגיע למקום שאני לא מכיר.דיברנו על זה.גם  לעזוב את הכל לרדת.מצד שני זה להתחיל מחדש. כן.
#
# ==========
# 72.0 doc
# 126.0 par[0]: confidence 0.935706
# Correct labeling:
# איזה כיף.
# Predicted labeling:
# איזה כיף.
#
# ==========
# 72.0 doc
# 139.0 par[0]: confidence 0.913096
# Correct labeling:
# ממש הוא גם אומר לי מה פתאום לא נוגע בזה.ו.
# Predicted labeling:
# ממש הוא גם אומר לי מה פתאום לא נוגע בזה.ו.
#
# ==========
# 72.0 doc
# 199.0 par[0]: confidence 0.996476
# Correct labeling:
# זה כמו שנגיד זה סוג של גם.ביטחון עצמי שאמור להיצבר בי.כי כמו שפעם התביישתי בזה שאני גיי.כאילו היו שואלים אותי נגיד הייתי בארון  בעצמי עם חוסר ביטחון.אני חושב שזה איזה משהו שמשפיע גם ברמה הזאת.
# Predicted labeling:
# זה כמו שנגיד זה סוג של גם.ביטחון עצמי שאמור להיצבר בי.כי כמו שפעם התביישתי בזה שאני גיי.כאילו היו שואלים אותי נגיד הייתי בארון  בעצמי עם חוסר ביטחון.אני חושב שזה איזה משהו שמשפיע גם ברמה הזאת.
#
# ==========
# 72.0 doc
# 233.0 par[0]: confidence 0.942784
# Correct labeling:
# נגיד הוא מתחיל את היום.מוקדם קם מתגלח שם את החולצה עניבה לא יודע מה בא לוקח את האוטו שלו שהוא.כאילו ה שיא תפארתו מעביר את האצבע מגיע.אומר שלום לאנשים קורא עיתון ככה זה כל יום אותו דבר.אני לא מסוגל לעשות את זה.אני עשיתי כאילו את זה.
# Predicted labeling:
# נגיד הוא מתחיל את היום.מוקדם קם מתגלח שם את החולצה עניבה לא יודע מה בא לוקח את האוטו שלו שהוא.כאילו ה שיא תפארתו מעביר את האצבע מגיע.אומר שלום לאנשים קורא עיתון ככה זה כל יום אותו דבר.אני לא מסוגל לעשות את זה.אני עשיתי כאילו את זה.
#
# ==========
# 72.0 doc
# 234.0 par[0]: confidence 0.913505
# Correct labeling:
# היית מאבטח?.
# Predicted labeling:
# היית מאבטח?.
#
# ==========
# 72.0 doc
# 267.0 par[0]: confidence 0.994130
# Correct labeling:
# שאין לי כוח אליהם ממ ו.יש בזה גם סיפוק.בעבודה הזאת שגם רואים תוצאות על האנשים.שמתאמנים שלך אומרים לך מה פתאום?.אתה לא עוזב אותי  בהחלט משמעות וזה כיף וזה טוב וזה מתגמל כאילו.מממ אבל אני מרגיש שאני כבר צריך כאילו ממש משהו חדש.
# Predicted labeling:
# שאין לי כוח אליהם ממ ו.יש בזה גם סיפוק.בעבודה הזאת שגם רואים תוצאות על האנשים.שמתאמנים שלך אומרים לך מה פתאום?.אתה לא עוזב אותי  בהחלט משמעות וזה כיף וזה טוב וזה מתגמל כאילו.מממ אבל אני מרגיש שאני כבר צריך כאילו ממש משהו חדש.
#
# ==========
# 72.0 doc
# 289.0 par[0]: confidence 0.986449
# Correct labeling:
# כן רגל אחת בחוץ.אני חושב שגם הם מרגישים את זה.
# Predicted labeling:
# כן רגל אחת בחוץ.אני חושב שגם הם מרגישים את זה.
#
# ==========
# 72.0 doc
# 306.0 par[0]: confidence 0.930637
# Correct labeling:
# מה היה קודם בהנאה הזאת עם העבודה?.כאילו מה היה?.
# Predicted labeling:
# מה היה קודם בהנאה הזאת עם העבודה?.כאילו מה היה?.
#
# ==========
# 72.0 doc
# 307.0 par[0]: confidence 0.907865
# Correct labeling:
# ממ.
# Predicted labeling:
# ממ.
#
# ==========
# 72.0 doc
# 309.0 par[0]: confidence 0.954257
# Correct labeling:
# פס יצור פס יצור.עושה סדנת בטן עושה חוג.עושה ספינינג עושה כמה אימונים ט הטה ט הטה טה.נגמר היום יושב מעשן סיגריה הולך למסיבה קם בבוקר עוד אימון אימון אימון אימון אימון.ככה זה כאילו היה.איפה אני פה ושם איך אני משדרג את רמת האימונים שלי איך אני מעלה את השכר שלי איך אני.ממ מפתח את ה עסק למרות שזה קצת נכבה לאחרונה.אבל ידעתי שזה עומד להיכבות כי אני ידעתי שאני עומד ורוצה להתפתח במקום שהוא אחר.מממ זהו רציתי כאילו יותר ללמוד מאשר ללמוד מהטעויות שלי.ללמוד מאנשים אחרים מאשר ללמוד כעצמאי מהטעויות שלי.
# Predicted labeling:
# פס יצור פס יצור.עושה סדנת בטן עושה חוג.עושה ספינינג עושה כמה אימונים ט הטה ט הטה טה.נגמר היום יושב מעשן סיגריה הולך למסיבה קם בבוקר עוד אימון אימון אימון אימון אימון.ככה זה כאילו היה.איפה אני פה ושם איך אני משדרג את רמת האימונים שלי איך אני מעלה את השכר שלי איך אני.ממ מפתח את ה עסק למרות שזה קצת נכבה לאחרונה.אבל ידעתי שזה עומד להיכבות כי אני ידעתי שאני עומד ורוצה להתפתח במקום שהוא אחר.מממ זהו רציתי כאילו יותר ללמוד מאשר ללמוד מהטעויות שלי.ללמוד מאנשים אחרים מאשר ללמוד כעצמאי מהטעויות שלי.
#
# ==========
# 72.0 doc
# 310.0 par[0]: confidence 0.902273
# Correct labeling:
# כי רצית להבין מה כדאי ומה זה לפני?.
# Predicted labeling:
# כי רצית להבין מה כדאי ומה זה לפני?.
#
# ==========
# 72.0 doc
# 312.0 par[0]: confidence 0.983292
# Correct labeling:
# של העסק?.
# Predicted labeling:
# של העסק?.
# ==========
# 72.0 doc
# 313.0 par[0]: confidence 0.969420
# Correct labeling:
# של העסק הוא צמח הוא צמח יפה.זאת אומרת  הוא עכשיו בדעיכה קלה כזאתי.בדעיכה לא קלה.דעיכה.
# Predicted labeling:
# של העסק הוא צמח הוא צמח יפה.זאת אומרת  הוא עכשיו בדעיכה קלה כזאתי.בדעיכה לא קלה.דעיכה.
#
# ==========
# 72.0 doc
# 314.0 par[0]: confidence 0.948461
# Correct labeling:
# כן אם היית רוצה היית מרים אותו.
# Predicted labeling:
# כן אם היית רוצה היית מרים אותו.
#
# ==========
# 72.0 doc
# 315.0 par[0]: confidence 0.986756
# Correct labeling:
# כן אם הייתי מספיק רוצה אז בהחלט.בשבועיים האחרונים עם כל המצעד וזה והכדורים האלה שעייפו אותי וזה.אז יש את ה.
# Predicted labeling:
# כן אם הייתי מספיק רוצה אז בהחלט.בשבועיים האחרונים עם כל המצעד וזה והכדורים האלה שעייפו אותי וזה.אז יש את ה.
#
# ==========
# 72.0 doc
# 317.0 par[0]: confidence 0.996990
# Correct labeling:
# מצד שני אני גם בסדר עם זה.
# Predicted labeling:
# מצד שני אני גם בסדר עם זה.
#
# ==========
# 72.0 doc
# 321.0 par[0]: confidence 0.989896
# Correct labeling:
# יב נגיד נעלם מהחיים.
# Predicted labeling:
# יב נגיד נעלם מהחיים.
#
# ==========
# 72.0 doc
# 326.0 par[0]: confidence 0.996718
# Correct labeling:
# זה לא מנהל אותך?.זה לא מפעיל אותך?.
# Predicted labeling:
# זה לא מנהל אותך?.זה לא מפעיל אותך?.
#
# ==========
# 72.0 doc
# 327.0 par[0]: confidence 0.988176
# Correct labeling:
# זה לא לא ממ וזה טוב לי.אני מאמין שהוא יראה אותי באיזה שהוא מקום והוא.או אני עדיין אדבר איתו.עשיתי טסט שבוע שעבר לקטנוע אמרתי לך?.
# Predicted labeling:
# זה לא לא ממ וזה טוב לי.אני מאמין שהוא יראה אותי באיזה שהוא מקום והוא.או אני עדיין אדבר איתו.עשיתי טסט שבוע שעבר לקטנוע אמרתי לך?.
#
# ==========
# 72.0 doc
# 328.0 par[0]: confidence 0.952079
# Correct labeling:
# אה באמת?.לא.
# Predicted labeling:
# אה באמת?.לא.
#
# ==========
# 72.0 doc
# 332.0 par[0]: confidence 0.919092
# Correct labeling:
# אהה מזל טוב.
# Predicted labeling:
# אהה מזל טוב.
#
# ==========
# 72.0 doc
# 333.0 par[0]: confidence 0.906936
# Correct labeling:
# תודה.
# Predicted labeling:
# תודה.
#
# ==========
# 72.0 doc
# 344.0 par[0]: confidence 0.941342
# Correct labeling:
# אז לקחת?.
# Predicted labeling:
# אז לקחת?.
#
# ==========
# 72.0 doc
# 345.0 par[0]: confidence 0.932262
# Correct labeling:
# עוד לא הוא עוד לא הביא.נראה מתי הוא יביא  קצת סטלן.אבל הוא יביא.
# Predicted labeling:
# עוד לא הוא עוד לא הביא.נראה מתי הוא יביא  קצת סטלן.אבל הוא יביא.
#
# ==========
# 72.0 doc
# 356.0 par[0]: confidence 0.978147
# Correct labeling:
# מעניין למה.
# Predicted labeling:
# מעניין למה.
#
# ==========
# 72.0 doc
# 357.0 par[0]: confidence 0.974814
# Correct labeling:
# ממ?.
# Predicted labeling:
# ממ?.
#
# ==========
# 72.0 doc
# 358.0 par[0]: confidence 0.956572
# Correct labeling:
# מעניין למה.
# Predicted labeling:
# מעניין למה.
#
# ==========
# 72.0 doc
# 359.0 par[0]: confidence 0.900623
# Correct labeling:
# כי הם שם רק.
# Predicted labeling:
# כי הם שם רק.
#
# ==========
# 72.0 doc
# 362.0 par[0]: confidence 0.994954
# Correct labeling:
# כן.
# Predicted labeling:
# כן.
#
# ==========
# 72.0 doc
# 363.0 par[0]: confidence 0.996713
# Correct labeling:
# האנרגיות שלהם הולכות לשם מאשר ל ולא משנה כמה הם נדלקים לא משנה כמה זה כיף להם כמה שזה עושה להם טוב.אולי אני צריך מישהו שהוא גם לא סטודנט.או שהוא לא סטודנט 100 אחוז.
# Predicted labeling:
# האנרגיות שלהם הולכות לשם מאשר ל ולא משנה כמה הם נדלקים לא משנה כמה זה כיף להם כמה שזה עושה להם טוב.אולי אני צריך מישהו שהוא גם לא סטודנט.או שהוא לא סטודנט 100 אחוז.
#
# ==========
# 72.0 doc
# 374.0 par[0]: confidence 0.952210
# Correct labeling:
# שקנית לך וליב איזה כרטיסים של איזה חופשה של משהו.
# Predicted labeling:
# שקנית לך וליב איזה כרטיסים של איזה חופשה של משהו.
#
# ==========
# 72.0 doc
# 375.0 par[0]: confidence 0.959118
# Correct labeling:
# אהה זה שבוע הבא.
# Predicted labeling:
# אהה זה שבוע הבא.
#
# ==========
# 72.0 doc
# 376.0 par[0]: confidence 0.949381
# Correct labeling:
# אתה נוסע?.
# Predicted labeling:
# אתה נוסע?.
#
# ==========
# 79.0 doc
# 4.0 par[0]: confidence 0.975827
# Correct labeling:
# להתקשר.
# Predicted labeling:
# להתקשר.
#
# ==========
# 79.0 doc
# 5.0 par[0]: confidence 0.978345
# Correct labeling:
# כן  אה  אבל XXX לאמא ו.אתמול יצאתי עם מישהי אני חושב לא בדיוק יצאתי כאילו היא הזמינה אותי לבוא איתה איזה אחת שאני מכיר כמה זמן דש בחורה נאה אישה נאה תמיד XXX נראית צעירה אני מקווה שאולי אה  היא אה שתי ילדות אני מכיר אותה הרבה שנים בסביבות 10 שנים אבל זה יצא דיי מוזר כי בעצם הייתי קודם בקשר עם אחותה  זה לא כמו XXX היא.
# Predicted labeling:
# כן  אה  אבל XXX לאמא ו.אתמול יצאתי עם מישהי אני חושב לא בדיוק יצאתי כאילו היא הזמינה אותי לבוא איתה איזה אחת שאני מכיר כמה זמן דש בחורה נאה אישה נאה תמיד XXX נראית צעירה אני מקווה שאולי אה  היא אה שתי ילדות אני מכיר אותה הרבה שנים בסביבות 10 שנים אבל זה יצא דיי מוזר כי בעצם הייתי קודם בקשר עם אחותה  זה לא כמו XXX היא.
#
# ==========
# 79.0 doc
# 44.0 par[0]: confidence 0.906125
# Correct labeling:
# סימני שאלה לגבי?.
# Predicted labeling:
# סימני שאלה לגבי?.
#
# ==========
# 79.0 doc
# 58.0 par[0]: confidence 0.943001
# Correct labeling:
# כי מה?.
# Predicted labeling:
# כי מה?.
#
# ==========
# 79.0 doc
# 59.0 par[0]: confidence 0.911677
# Correct labeling:
#  למה היא היא עשתה היא אה היא פעלה בחוסר XXX במקרה הזה זאת אומרת היא עשתה מה שהיא כהבנתה אבל זה לא נכון זאת אומרת להכניס אליו XXX אה זאת אומרת היא לא לא שערה את הסיפור.האובדנות שלו עכשיו היא יכולה להיות יכול להיות שהיא מפחדת שהתוצאות אה אז אה.
# Predicted labeling:
#  למה היא היא עשתה היא אה היא פעלה בחוסר XXX במקרה הזה זאת אומרת היא עשתה מה שהיא כהבנתה אבל זה לא נכון זאת אומרת להכניס אליו XXX אה זאת אומרת היא לא לא שערה את הסיפור.האובדנות שלו עכשיו היא יכולה להיות יכול להיות שהיא מפחדת שהתוצאות אה אז אה.
#
# ==========
# 79.0 doc
# 64.0 par[0]: confidence 0.974831
# Correct labeling:
# זה זאת אומרת  פעם ראשונה מזה הרבה זמן שאתה חווה התפרצות או שהיו לך עוד כל מיני בזמן האחרון?.
# Predicted labeling:
# זה זאת אומרת  פעם ראשונה מזה הרבה זמן שאתה חווה התפרצות או שהיו לך עוד כל מיני בזמן האחרון?.
#
# ==========
# 79.0 doc
# 129.0 par[0]: confidence 0.915066
# Correct labeling:
# אני אהיה אני לא לא זה לא לא עוד הירושימה לא עוד XXX.
# Predicted labeling:
# אני אהיה אני לא לא זה לא לא עוד הירושימה לא עוד XXX.

# %%
check_doc =[(12,97),(14,47),(15,93),(18,15),(79,5)]
looks_like_nar=[(28,55),(32,20),(55,30),(55,136)]

# %%
for i in check_doc[1:2]:
    print(i)
    doc_db = pred_info_df.query("doc_idx == @i[0] and par_idx_in_doc == @i[1]")
    print(doc_db['text'].tolist())
    break
# Out:
# (14, 47)
# ['אני לא יודע מה השתנה', 'אני חושב שזה גם סוג של מה שקורה בלימודים', 'שאם פעם הייתה לי את המוטיבציה הזאת אז היום גם אין לי את המוטיבציה הזאת', 'אני לא יודע איך יש קשר בין הדברים אני רק יודע שזה בא ביחד', 'כי כשירד שם גם ירד שם', 'כאילו ה הרצון ונגיד עכשיו שהייתי צריך לשלם את החודש הזה', 'אז אמרתי לעצמי', 'כאילו אתמול או שלשום אמרתי לעצמי', 'טוב אני אלך מתי שהוא לבנק', 'ו אתמול אמרתי את זה', 'אמרתי אני אלך מתי שהוא לבנק', 'והיום בדרך בנסיעה', 'אמרתי לא זה לא אפשרי אני לא יכול כל דבר ככה לדחות', 'ונסעתי לבנק שזה לא באמת סיפור זה 2 דקות', 'אבל זה כאילו משהו נכנס למחשבה שכל משימה זה כזה', 'טוב אני אעשה את זה מתי שהוא', 'לדחות דברים נותנים לי איזה טלפון שאני צריך להתקשר לבן אדם לדבר איתו אני אעשה את זה מתי שהוא', 'הכל לדחות דברים לדחות וזה לא פיתרון כי מתי שהוא צריך לעשות את זה', 'אי אפשר לדחות את זה', 'זה בא ביחד', 'זה כאילו זה דברים שאני שם לב תוך כדי', 'כמו ששמתי לב נגיד ש', 'יש בווטסאפ הכניסו את הפיצר הזה בשנה או בשנתיים האחרונות שאפשר לראות מי נראה לאחרונה או מי קרא את ההודעה', 'יש כזה אפשרות לראות', 'כאילו רואים אם בן אדם התחבר או לא התחבר', 'ואני משתמש הרבה בווטסאפ כן?', 'וקבוצות של האוניברסיטה וכל מיני', 'וזה ממש אני ביום שישי חבר נתן לי הזמנה', 'והוא כתב הקדשה בהזמנה', 'שם לי את זה בדואר', 'הוא כתב לי שמתי לך את ההזמנה בדואר', 'עכשיו אני ידעתי שאחרי שאני אקרא אני אכתוב לו איזה יופי', 'אני אכתוב לו תגובה או משהו כזה', 'והבאתי את ההזמנה הביתה וה', 'והמחשבה הראשונית שלי הייתה', 'אל תפתח עדין את ההזמנה', 'זאת אומרת אל תקרא', 'כי אז אתה תצטרך לענות לו', 'ואמרתי זה מחשבה מטומטמת כי זה לא ווטסאפ הוא לא רואה אם ראית או לא', 'ופתאום שמתי לב', 'הייתי מודע לזה שאני בעצם חי את הווטסאפ', 'ו פתאום אני מודע כאילו למחשבות שלי', 'באותה מידה אני מודע פתאום לעניין הזה של הדחייה של הדברים', 'שלאחרונה אני כל משימה שנותנים לי', 'בעבודה זה קצת פחות בא לידי ביטוי', 'כי נותנים לי משימות אז זה המשימות שאני צריך לעשות', 'כאילו אני לא יכול לדחות אותן יותר מידי', 'אני יכול לשחק עם זה טיפה', 'מה קודם אבל אני לא יכול לא לעשות יש לי בוס', 'יש לי אני צריך לעמוד בזמנים', 'אבל משימות של היומיום זה כאילו', 'ואני מתפלא על עצמי', 'כי אני לא זוכר', 'בעבר לא הייתי כזה', 'אחי כזה אח שלי הוא כזה שאומרים לו תרד תביא', 'תקנה חלב טוב בסדר מה הלחץ אחר כך אני אעשה', 'ותמיד הייתי מסתכל עליו בכזה מה בעיה למה לא תרד עכשיו?', 'אני אם היו אומרים לי הייתי יור במקום', 'לא יודע אם זה קשור ללימודים או לא אבל שניהם דברים שאני שם לב שקורים']

# %%
err_docs = err_pred_info['doc_idx'].unique()
for doc_idx in err_docs[:1]:
    sent_db = pd.read_csv(os.path.join(db_path,"{:02d}_sent_db.csv".format(int(doc_idx))))
    doc_samples = err_pred_info.query("doc_idx == @doc_idx")
    err_par_of_doc = doc_samples['par_idx_in_doc'].unique()
    for par_idx in err_par_of_doc:
        par_samples = doc_samples.query("par_idx_in_doc == @par_idx")
        for par in par_samples.index:
#             sent
            display (sent_db.loc[par_samples])
    

# for i,idx in enumerate(list(err_pred_info.index)[:3]):
#     doc_idx = int(err_pred_info.loc[idx,'doc_idx'])
#     par_idx = int(err_pred_info.loc[idx,'par_idx_in_doc'])
#     sent_db = pd.read_csv(os.path.join(db_path,"{:02d}_sent_db.csv".format(doc_idx)))
#     err_par = sent_db.query("par_idx_in_doc == @par_idx")['text']
#     display(err_par)
#     print("{}: {}".format(i,err_par))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-444e4a2209c3> in <module>
#       8         for par in par_samples.index:
#       9 #             sent
# ---> 10             display (sent_db.loc[par_samples])
#      11
#      12
#
# ~/jupyter_git/jup-nb-generic/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/jupyter_git/jup-nb-generic/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1109
#    1110                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
#    1113                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
from termcolor import colored
print(colored('hello', 'red'), colored('world', 'green'))
print(colored("hello red world", 'red'))
# Out:
# hello world
# hello red world

# %% [markdown]
# ## Merge error and correct sentenses into single df

# %%
compare_df = pd.concat([err_pred_info,corr_pred_info],keys=['error','correct'])
compare_df.reset_index(inplace=True)
compare_df.rename(columns={'level_0':'prediction'},inplace=True)
compare_df
# Out:
#      prediction  level_1    seq_idx  idx_in_seq   doc_idx   seq_len  label  \
# 0         error        0 454.000000    0.000000 12.000000 44.000000   True
# 1         error        1 498.000000   72.000000 14.000000 74.000000  False
# 2         error        2 498.000000   69.000000 14.000000 74.000000  False
# 3         error        3 816.000000   12.000000 29.000000 28.000000   True
# 4         error        4 498.000000   68.000000 14.000000 74.000000  False
# ...         ...      ...        ...         ...       ...       ...    ...
# 5373    correct     4731 157.000000    8.000000  4.000000 16.000000   True
# 5374    correct     4732 742.000000   10.000000 28.000000 20.000000  False
# 5375    correct     4733   2.000000   21.000000 32.000000 24.000000   True
# 5376    correct     4734 196.000000    2.000000 36.000000  4.000000  False
# 5377    correct     4735 809.000000   14.000000 29.000000 16.000000  False
#
#        pred  pred_proba   is_nar  is_client   sent_len  par_idx_in_doc  \
# 0     False    0.999994 1.000000   0.000000  25.000000       64.000000
# 1      True    0.999983 0.000000   1.000000  36.000000       47.000000
# 2      True    0.999919 0.000000   1.000000  42.000000       47.000000
# 3     False    0.999886 1.000000   0.000000  17.000000       95.000000
# 4      True    0.999858 0.000000   1.000000  17.000000       47.000000
# ...     ...         ...      ...        ...        ...             ...
# 5373   True    0.900568 1.000000   1.000000  15.000000       61.000000
# 5374  False    0.900560 0.000000   0.000000  40.000000       40.000000
# 5375   True    0.900316 1.000000   1.000000 132.000000        8.000000
# 5376  False    0.900218 0.000000   1.000000 305.000000       47.000000
# 5377  False    0.900117 0.000000   0.000000  81.000000       75.000000
#
#       sent_idx_in_par  is_question  \
# 0            0.000000     1.000000
# 1           57.000000     0.000000
# 2           54.000000     0.000000
# 3            0.000000     1.000000
# 4           53.000000     0.000000
# ...               ...          ...
# 5373         7.000000     0.000000
# 5374         5.000000     0.000000
# 5375         1.000000     0.000000
# 5376         0.000000     0.000000
# 5377         2.000000     0.000000
#
#                                                    text     TOKEN
# 0                             אז לא ברור לימה אתה רוצה?  6.000000
# 1                  אני אם היו אומרים לי הייתי יור במקום  8.000000
# 2            אחי כזה אח שלי הוא כזה שאומרים לו תרד תביא 10.000000
# 3                                      אבל אתה מנהל שם?  4.000000
# 4                                     בעבר לא הייתי כזה  4.000000
# ...                                                 ...       ...
# 5373                                    לפעמים אני עונה  3.000000
# 5374           over  לדאוג לך over לא ליפול שם באיזה פח  8.000000
# 5375  נגיד אני מסתכלת על הנייר אז איזה ימים יש לי או... 26.000000
# 5376    טוב אז גדלתי עם בית שאבא שלי הוא היה מאוד דו... 38.000000
# 5377  במובן שכאילו אתה מרגיש שהשני קיבל את שלו ואתה ... 17.000000
#
# [5378 rows x 17 columns]

# %%
all_columns = set(compare_df.columns)
exclude_columns  = set(['label','pred','prediction','level_1','seq_idx','doc_idx','pred_proba','text'])
include_columns = all_columns-exclude_columns

for i,col in enumerate(include_columns):
    plot =  sns.displot(data=compare_df,
                        x=col,
                       hue = 'prediction',
                        common_norm=False,
                         kind='kde'
                       )
    plot.set(xlim=(compare_df[col].min(),compare_df[col].max()),title=col)
    plt.grid()

# %% [markdown]
# ## View error pattern in sequences

# %% [markdown]
# ### Detect samples with high error ratio per sequence

# %%
def f(group):
    return pd.DataFrame({'seq_idx': group['seq_idx'],
                         'idx_in_seq': group['idx_in_seq'],
                         'err_ratio': len(group)/group['seq_len']})

grouped=err_pred_info.groupby('seq_idx')
seq_err_ratio = grouped.apply(f)
uniq = seq_err_ratio.drop_duplicates(subset='seq_idx', inplace=False, ignore_index=True)
uniq_sorted = uniq.sort_values(by='err_ratio',ascending=False)
uniq_sorted['err_ratio'].hist()

# %%
seq_err_ratio

# %%
entire_seq_err = uniq_sorted.query('err_ratio == 1')['seq_idx'].tolist()

# %%
err_pred_info.query("seq_idx in @entire_seq_err").sort_values(by=['seq_idx','idx_in_seq'])

# %% [markdown]
# ## TODO:
# 1. find what patterns are popular [false-false-true...]
# 2. try to catch differences between correct & error pattern

# %%
def calc_err_ratio(grp):
#     print("grp size {} seq len {}".format(grp.size,set(grp['seq_len'])))
    grp['err_ratio'] = len(grp)/grp['seq_len']
    return grp
 
new_df=err_pred_info.groupby('seq_idx').apply(lambda x: len(x)/x['seq_len'])
new_df
# err_pred_info.groupby("seq_idx").transform(calc_err_ratio)

# %%
err_pred_info

# %%
error_features_df = pd.DataFrame()
keys = ['sent_len','is_client','sent_idx_in_par','par_idx_in_doc','TOKEN']
def add_sent_info(_pred_df):
    pred_df = _pred_df.copy()
    for idx,row in _pred_df.iterrows():
        err_sent = X_test[int(row['seq_idx'])][int(row['idx_in_seq'])]
        for key in keys:
            pred_df.loc[idx,key] =  err_sent[key]
    return pred_df

info_strong_err = add_sent_info(strong_err)
info_strong_err

# %%
info_strong_corr = add_sent_info(strong_corr)
info_strong_corr

# %%
compare_df = pd.concat([info_strong_err,info_strong_corr],keys=['error','correct'])
compare_df.reset_index(inplace=True)
compare_df.rename(columns={'level_0':'prediction'},inplace=True)
compare_df

# %%
all_columns = set(compare_df.columns)
exclude_columns  = set(['label','pred','prediction','level_1'])
include_columns = all_columns-exclude_columns

for i,col in enumerate(include_columns):
    plot =  sns.displot(data=compare_df,
                        x=col,
                       hue = 'prediction',
                        common_norm=False,
                         kind='kde'
                       )
    plot.set(xlim=(compare_df[col].min(),compare_df[col].max()),title=col)
    plt.grid()

# %%
docs_map_sent = feature_utils.pack_all_doc_sentences_to_map(per_par=False,limit=0,sent_lemma_db_list=[])

# %%
imp.reload(feature_utils)
feature_utils.reshape_docs_map_to_seq(docs_map_sent,per_par=False,seq_len=8,step=8)

# %%
test_percent = 0.25
X_train,y_train,X_test,y_test,test_idx,groups_train,groups_test =  split_test_train_docs(docs_map_sent,test_percent)

# %%
X_test[3]

# %%
crf = CRF(
    min_freq = 5,
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True,
    )
crf.fit(X_train, y_train)
y_pred  =  crf.predict(X_test)
labels = list(crf.classes_)
f1 = metrics.flat_f1_score(y_test, y_pred,average='weighted', labels=labels)
recall = metrics.flat_recall_score(y_test, y_pred,average='weighted', labels=labels)
precision = metrics.flat_precision_score(y_test, y_pred,average='weighted', labels=labels)
print ("f1 {}\nrecall {}\nprecition {}".format(f1,recall,precision))

# %%
score =  manual_groups_validate(docs_map_sent,test_percent,num_splits=10)
feature_utils.add_score_to_db(score_db_man,"3_3_man_sent",score)

# %%
score_db_man

# %%
mer_db =   pd.read_csv(r"./dataframes/{:02d}_merged_db.csv".format(int(groups_test[0])))
mer_db.head()

# %%
for i,row in enumerate(X_test):
    for j,item in enumerate(row):
        if not 'is_client' in item:
            print("No client tag in X_test[{}][{}]".format(i,j))

# %%
for index,row in pred_sent_db.iterrows():
    display(row.transpose())
    break

# %%
len(groups_test), len(y_test)

# %% [markdown]
# # TODO
# [] retrive all strong wrong  / strong correct sentences
# [] check the difference

# %%
groups_test[int(err_df.loc[0,'seq_idx'])]

# %%
test_doc_idx = groups_test[int(err_df.loc[0,'seq_idx'])]
print ("Test doc idx = {}".format(test_doc_idx))
sent_db =  pd.read_csv(r"./dataframes/{:02d}_sent_db.csv".format(test_doc_idx))

# %%
sent_db.query("par_idx_in_doc == @error_sent['par_idx_in_doc'] and sent_idx_in_par == @error_sent['sent_idx_in_par']")

# %%
test_idx

# %%
len(y_pred),len(flatten(y_pred))

# %%
len(X_test)

# %% [markdown]
# ### Cross-validate

# %%
score_db = pd.DataFrame()

# %%
imp.reload(feature_utils)
shapes = [(3,3), # sequence [1:3][4:6]...
          (3,2), # sequence [1:3][3:7]...
          (3,1)] # sequence [1:3][2:4][3:5]...
n_groups = 80 # len(set(groups_plane))
test_percent = 0.40
norm = 1
normed = "norm" if norm else ""
prefix = "no_limit"
n_splits = int(n_groups*test_percent)
n_out = int(n_groups/n_splits)
if n_out == 1:
    logo = LeaveOneGroupOut()
else:
#     logo = LeavePGroupsOut(n_groups=num_out)
    logo = GroupKFold(n_splits=n_splits)
#     print(logo.get_n_splits(X_plane,y_plane,groups_plane))

for shape in shapes[1:2]:
    seq_len = shape[0]
    step = shape[1]
#     X_shaped,y_shaped,groups_shaped = feature_utils.reshape_doc_paragraphs_to_sequence(X_plane,y_plane,groups_plane,seq_len,step)
#     X_shaped,y_shaped,groups_shaped = feature_utils.reshape_docs_map_to_seq(docs_map,seq_len,step)
    score = feature_utils.leave_out_validate(X_shaped,y_shaped,groups_shaped,logo)
    feature_utils.add_score_to_db(score_db,"{}_len{}_step{}_{}".format(prefix,seq_len,step,normed),score)

# %%
score_db

# %%
score_db.to_csv("./dataframes/score_max_len8.csv",index=False)
